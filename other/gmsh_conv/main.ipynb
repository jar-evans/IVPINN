# %% [markdown]
# # Full Dirichlet VPINN example

# %%
from MeshLib import MeshLib as ml

from VPINN_tri_final import *

from PROBDEF import PROBDEF

import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import logging; logging.getLogger('tensorflow').setLevel(logging.ERROR)

tfk = tf.keras
tfkl = tf.keras.layers

# importing probdef 
pb = PROBDEF()
# Out:
# 2023-12-07 18:44:27.581009: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-07 18:44:27.597902: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-07 18:44:27.798591: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-07 18:44:27.800091: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-07 18:44:28.742183: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# my_types lib imported
#
# MeshLib imported
#
# generate mesh lib imported
#
# interpolator_lib imported
#
# settings_lib imported

# %% [markdown]
# ### Initialise mesh

# %%
# seed for reproducibility
initializer = tf.keras.initializers.GlorotUniform(seed=54)


# mesh init
domain = ((0, 0), (1, 0), (1, 1), (0, 1))
#mesh = generate_mesh(domain, 0.01)

# %% [markdown]
# ### Train boundary condition network

# %%
#net used for approximating the fully dirichlet bc  
bc_model = tfk.models.Sequential()
bc_model.add(tf.keras.Input(shape=(2,),dtype=tf_type))
bc_model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
bc_model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
bc_model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
bc_model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
bc_model.add(tf.keras.layers.Dense(1,activation='linear',kernel_initializer=initializer,dtype=tf_type,use_bias=True))

# %%
print(bc_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 371 (2.90 KB)
# Trainable params: 371 (2.90 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# setting model to the current net
model = bc_model


# helper function to treat the net as a lamda function
def model_np(x, y):
    eval = tf.constant([[x, y]], dtype=tf.float64)
    return model(eval).numpy()[0, 0]

# %%
def plot_BC(u_exact, u_NN_BC_):
    """both numpy functions"""
    x = np.linspace(0, 1, 200, dtype=np.float64)

    eval_exact = [u_exact(x[i], 1.0) for i in range(len(x))]

    eval_net = [u_NN_BC_(x[i], 1.0) for i in range(len(x))]

    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    plt.figure(figsize=(10,7))  # Set the figure size

    # Plot the data
    plt.subplot(221)   
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("top edge")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.0) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.0) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(223)    
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("bottom edge")
    plt.legend()

    eval_exact = [u_exact(1.0, x[i]) for i in range(len(x))]
    eval_net = [u_NN_BC_(1.0, x[i]) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(222)    
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("right edge")
    plt.legend()

    eval_exact = [u_exact(0.0, x[i]) for i in range(len(x))]
    eval_net = [u_NN_BC_(0.0, x[i]) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(224)   
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("left edge")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.5) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.5) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    plt.figure(figsize=(10, 7))  # Set the figure size

    # Plot the data
    plt.subplot(221)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle y=0.5")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.25) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.25) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(222)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle y=0.25")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.75) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.75) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(223)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle y=0.75")
    plt.legend()

    eval_exact = [u_exact(0.5, x[i]) for i in range(len(x))]
    eval_net = [u_NN_BC_(0.5, x[i]) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(224)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle x=0.50")
    plt.legend()

def helper_colour_plot(x, y, model):

    x_=tf.reshape(x,(-1,1))
    y_=tf.reshape(y,(-1,1))

    eval=tf.concat([x_,y_],axis=1)

    return tf.reshape(model(eval),(tf.shape(x)[0],-1))

def color_plot(model):

    x = np.linspace(0, 1, 1000)
    y = np.linspace(0, 1, 1000)

    X, Y = np.meshgrid(x, y)

    error = np.abs(pb.u_exact_np(X,Y)-helper_colour_plot(X,Y,model))

    fig=plt.imshow(
        error,
        extent=[min(x), max(x), min(y), max(y)],
        vmin=np.min(error),
        vmax=np.max(error)
    )

    plt.title('Error Map')
    plt.colorbar(fig)

    fig.axes.set_autoscale_on(False)

# %%
# Compare untrained model to the exact version
plot_BC(pb.u_exact_np,model_np)

# %%
color_plot(bc_model)

# %%
# Generate training data for the network
x = pb.generate_boundary_points(30, False)
plt.scatter(x[:, 0], x[:, 1])
plt.title("Training points - bc_model")
plt.grid()

y = pb.u_exact(x[:, 0], x[:, 1])
y = tf.reshape(y, (-1, 1))

# %%
# Training process of bc_model with the MSE as loss function 
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Adjust the learning rate as needed
bc_model.compile(optimizer=custom_optimizer, loss='mean_squared_error')

history=model.fit(x, y, epochs=3000, batch_size=np.size(y))
# Out:
# Epoch 1/3000
# 1/1 [==============================] - 1s 620ms/step - loss: 1.0634
# Epoch 2/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0161
# Epoch 3/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9720
# Epoch 4/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9312
# Epoch 5/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8936
# Epoch 6/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8591
# Epoch 7/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8275
# Epoch 8/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7985
# Epoch 9/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7718
# Epoch 10/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7472
# Epoch 11/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7243
# Epoch 12/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7029
# Epoch 13/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6827
# Epoch 14/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6635
# Epoch 15/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6452
# Epoch 16/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6274
# Epoch 17/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6103
# Epoch 18/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5936
# Epoch 19/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5773
# Epoch 20/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5614
# Epoch 21/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5460
# Epoch 22/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5309
# Epoch 23/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5163
# Epoch 24/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5021
# Epoch 25/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4884
# Epoch 26/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4752
# Epoch 27/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4624
# Epoch 28/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4500
# Epoch 29/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4381
# Epoch 30/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4265
# Epoch 31/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4153
# Epoch 32/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4044
# Epoch 33/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3937
# Epoch 34/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3833
# Epoch 35/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3731
# Epoch 36/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3631
# Epoch 37/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3532
# Epoch 38/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3436
# Epoch 39/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3341
# Epoch 40/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3249
# Epoch 41/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3158
# Epoch 42/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3069
# Epoch 43/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2982
# Epoch 44/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2897
# Epoch 45/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2814
# Epoch 46/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2732
# Epoch 47/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2653
# Epoch 48/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2576
# Epoch 49/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2500
# Epoch 50/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2427
# Epoch 51/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2355
# Epoch 52/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2285
# Epoch 53/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2216
# Epoch 54/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2150
# Epoch 55/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2086
# Epoch 56/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2024
# Epoch 57/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1964
# Epoch 58/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1907
# Epoch 59/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1852
# Epoch 60/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1799
# Epoch 61/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1748
# Epoch 62/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1700
# Epoch 63/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1655
# Epoch 64/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1611
# Epoch 65/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1570
# Epoch 66/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1532
# Epoch 67/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1495
# Epoch 68/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1461
# Epoch 69/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1429
# Epoch 70/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1400
# Epoch 71/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1372
# Epoch 72/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1346
# Epoch 73/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1323
# Epoch 74/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1301
# Epoch 75/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1281
# Epoch 76/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1262
# Epoch 77/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1245
# Epoch 78/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1230
# Epoch 79/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1216
# Epoch 80/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1202
# Epoch 81/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1190
# Epoch 82/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1179
# Epoch 83/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1169
# Epoch 84/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1159
# Epoch 85/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1150
# Epoch 86/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1141
# Epoch 87/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1133
# Epoch 88/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1126
# Epoch 89/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1118
# Epoch 90/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1111
# Epoch 91/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1104
# Epoch 92/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1098
# Epoch 93/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1091
# Epoch 94/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1085
# Epoch 95/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1078
# Epoch 96/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1072
# Epoch 97/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1066
# Epoch 98/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1060
# Epoch 99/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1053
# Epoch 100/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1047
# Epoch 101/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1041
# Epoch 102/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1035
# Epoch 103/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1030
# Epoch 104/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1024
# Epoch 105/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1018
# Epoch 106/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1012
# Epoch 107/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1007
# Epoch 108/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1001
# Epoch 109/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0996
# Epoch 110/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0991
# Epoch 111/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0985
# Epoch 112/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0980
# Epoch 113/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0975
# Epoch 114/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0970
# Epoch 115/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0966
# Epoch 116/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 117/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0956
# Epoch 118/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0952
# Epoch 119/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0947
# Epoch 120/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0943
# Epoch 121/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0938
# Epoch 122/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0934
# Epoch 123/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0930
# Epoch 124/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0926
# Epoch 125/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0922
# Epoch 126/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0918
# Epoch 127/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0914
# Epoch 128/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0910
# Epoch 129/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0906
# Epoch 130/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0903
# Epoch 131/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0899
# Epoch 132/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0895
# Epoch 133/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0892
# Epoch 134/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0888
# Epoch 135/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0885
# Epoch 136/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0881
# Epoch 137/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0878
# Epoch 138/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0875
# Epoch 139/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0871
# Epoch 140/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0868
# Epoch 141/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0865
# Epoch 142/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0861
# Epoch 143/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0858
# Epoch 144/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0855
# Epoch 145/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 146/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0849
# Epoch 147/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0846
# Epoch 148/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0843
# Epoch 149/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0840
# Epoch 150/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0837
# Epoch 151/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0834
# Epoch 152/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0831
# Epoch 153/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0829
# Epoch 154/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0826
# Epoch 155/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 156/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0820
# Epoch 157/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0818
# Epoch 158/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0815
# Epoch 159/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0813
# Epoch 160/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0810
# Epoch 161/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0807
# Epoch 162/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0805
# Epoch 163/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0802
# Epoch 164/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0800
# Epoch 165/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0797
# Epoch 166/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0795
# Epoch 167/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0793
# Epoch 168/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0790
# Epoch 169/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0788
# Epoch 170/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0786
# Epoch 171/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0783
# Epoch 172/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0781
# Epoch 173/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0779
# Epoch 174/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0777
# Epoch 175/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0774
# Epoch 176/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0772
# Epoch 177/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0770
# Epoch 178/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0768
# Epoch 179/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0766
# Epoch 180/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0764
# Epoch 181/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0762
# Epoch 182/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0760
# Epoch 183/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0758
# Epoch 184/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0756
# Epoch 185/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0754
# Epoch 186/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0752
# Epoch 187/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0750
# Epoch 188/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0748
# Epoch 189/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0746
# Epoch 190/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0744
# Epoch 191/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0742
# Epoch 192/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0740
# Epoch 193/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0738
# Epoch 194/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0737
# Epoch 195/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0735
# Epoch 196/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0733
# Epoch 197/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0731
# Epoch 198/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0729
# Epoch 199/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0728
# Epoch 200/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0726
# Epoch 201/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0724
# Epoch 202/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0722
# Epoch 203/3000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0721
# Epoch 204/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0719
# Epoch 205/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0717
# Epoch 206/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0716
# Epoch 207/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 208/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0712
# Epoch 209/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0711
# Epoch 210/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0709
# Epoch 211/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 212/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0706
# Epoch 213/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0704
# Epoch 214/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0703
# Epoch 215/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 216/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0699
# Epoch 217/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0698
# Epoch 218/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 219/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0695
# Epoch 220/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0693
# Epoch 221/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0692
# Epoch 222/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0690
# Epoch 223/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 224/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 225/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0686
# Epoch 226/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0684
# Epoch 227/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0683
# Epoch 228/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0681
# Epoch 229/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0680
# Epoch 230/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0678
# Epoch 231/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0677
# Epoch 232/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0676
# Epoch 233/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0674
# Epoch 234/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0673
# Epoch 235/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0671
# Epoch 236/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0670
# Epoch 237/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0668
# Epoch 238/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 239/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0666
# Epoch 240/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0664
# Epoch 241/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0663
# Epoch 242/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0662
# Epoch 243/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0660
# Epoch 244/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 245/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0657
# Epoch 246/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0656
# Epoch 247/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0655
# Epoch 248/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0653
# Epoch 249/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0652
# Epoch 250/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0651
# Epoch 251/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0649
# Epoch 252/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0648
# Epoch 253/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0647
# Epoch 254/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0645
# Epoch 255/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0644
# Epoch 256/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0643
# Epoch 257/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0641
# Epoch 258/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0640
# Epoch 259/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 260/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0637
# Epoch 261/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 262/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0635
# Epoch 263/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0634
# Epoch 264/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 265/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 266/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0630
# Epoch 267/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 268/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0627
# Epoch 269/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0626
# Epoch 270/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0624
# Epoch 271/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0623
# Epoch 272/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0622
# Epoch 273/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0621
# Epoch 274/3000
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0619
# Epoch 275/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0618
# Epoch 276/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0617
# Epoch 277/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0616
# Epoch 278/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0614
# Epoch 279/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0613
# Epoch 280/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0612
# Epoch 281/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0611
# Epoch 282/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0609
# Epoch 283/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0608
# Epoch 284/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0607
# Epoch 285/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0605
# Epoch 286/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0604
# Epoch 287/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0603
# Epoch 288/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0602
# Epoch 289/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0600
# Epoch 290/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 291/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0598
# Epoch 292/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0597
# Epoch 293/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 294/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0594
# Epoch 295/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0593
# Epoch 296/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0592
# Epoch 297/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0590
# Epoch 298/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0589
# Epoch 299/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 300/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0587
# Epoch 301/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0586
# Epoch 302/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0584
# Epoch 303/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0583
# Epoch 304/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0582
# Epoch 305/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0581
# Epoch 306/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0579
# Epoch 307/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0578
# Epoch 308/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0577
# Epoch 309/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0576
# Epoch 310/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0574
# Epoch 311/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0573
# Epoch 312/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 313/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0571
# Epoch 314/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0569
# Epoch 315/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0568
# Epoch 316/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0567
# Epoch 317/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0566
# Epoch 318/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0564
# Epoch 319/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0563
# Epoch 320/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0562
# Epoch 321/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0561
# Epoch 322/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0559
# Epoch 323/3000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0558
# Epoch 324/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0557
# Epoch 325/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0556
# Epoch 326/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0554
# Epoch 327/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0553
# Epoch 328/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0552
# Epoch 329/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0550
# Epoch 330/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0549
# Epoch 331/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0548
# Epoch 332/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0547
# Epoch 333/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0545
# Epoch 334/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0544
# Epoch 335/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0543
# Epoch 336/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0542
# Epoch 337/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0540
# Epoch 338/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0539
# Epoch 339/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0538
# Epoch 340/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0537
# Epoch 341/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0535
# Epoch 342/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0534
# Epoch 343/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0533
# Epoch 344/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0531
# Epoch 345/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0530
# Epoch 346/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0529
# Epoch 347/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0527
# Epoch 348/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0526
# Epoch 349/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0525
# Epoch 350/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0524
# Epoch 351/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0522
# Epoch 352/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0521
# Epoch 353/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0520
# Epoch 354/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0518
# Epoch 355/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0517
# Epoch 356/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0516
# Epoch 357/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0514
# Epoch 358/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0513
# Epoch 359/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0512
# Epoch 360/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0510
# Epoch 361/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 362/3000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0508
# Epoch 363/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0506
# Epoch 364/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0505
# Epoch 365/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0504
# Epoch 366/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0502
# Epoch 367/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0501
# Epoch 368/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0500
# Epoch 369/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0498
# Epoch 370/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0497
# Epoch 371/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0496
# Epoch 372/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0494
# Epoch 373/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0493
# Epoch 374/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0492
# Epoch 375/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0490
# Epoch 376/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0489
# Epoch 377/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0487
# Epoch 378/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0486
# Epoch 379/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0485
# Epoch 380/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0483
# Epoch 381/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0482
# Epoch 382/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0481
# Epoch 383/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0479
# Epoch 384/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0478
# Epoch 385/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0476
# Epoch 386/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0475
# Epoch 387/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0473
# Epoch 388/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0472
# Epoch 389/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0471
# Epoch 390/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0469
# Epoch 391/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0468
# Epoch 392/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0466
# Epoch 393/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0465
# Epoch 394/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0463
# Epoch 395/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0462
# Epoch 396/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0461
# Epoch 397/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0459
# Epoch 398/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0458
# Epoch 399/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0456
# Epoch 400/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0455
# Epoch 401/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0453
# Epoch 402/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0452
# Epoch 403/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0450
# Epoch 404/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0449
# Epoch 405/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0447
# Epoch 406/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0446
# Epoch 407/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0444
# Epoch 408/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0443
# Epoch 409/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0441
# Epoch 410/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0440
# Epoch 411/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0438
# Epoch 412/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0437
# Epoch 413/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0435
# Epoch 414/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0433
# Epoch 415/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0432
# Epoch 416/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0430
# Epoch 417/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0429
# Epoch 418/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0427
# Epoch 419/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0426
# Epoch 420/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0424
# Epoch 421/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0423
# Epoch 422/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0421
# Epoch 423/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0419
# Epoch 424/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0418
# Epoch 425/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0416
# Epoch 426/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0415
# Epoch 427/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0413
# Epoch 428/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0411
# Epoch 429/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0410
# Epoch 430/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0408
# Epoch 431/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0407
# Epoch 432/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0405
# Epoch 433/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0403
# Epoch 434/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0402
# Epoch 435/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0400
# Epoch 436/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0398
# Epoch 437/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0397
# Epoch 438/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0395
# Epoch 439/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0393
# Epoch 440/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0392
# Epoch 441/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0390
# Epoch 442/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0388
# Epoch 443/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0387
# Epoch 444/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0385
# Epoch 445/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0383
# Epoch 446/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0382
# Epoch 447/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0380
# Epoch 448/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0378
# Epoch 449/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0376
# Epoch 450/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0375
# Epoch 451/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0373
# Epoch 452/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 453/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0370
# Epoch 454/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0368
# Epoch 455/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0366
# Epoch 456/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0364
# Epoch 457/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0363
# Epoch 458/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 459/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0359
# Epoch 460/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 461/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0356
# Epoch 462/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0354
# Epoch 463/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 464/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0350
# Epoch 465/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0348
# Epoch 466/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0347
# Epoch 467/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 468/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 469/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0341
# Epoch 470/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 471/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0338
# Epoch 472/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 473/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 474/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 475/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0331
# Epoch 476/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 477/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0327
# Epoch 478/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0325
# Epoch 479/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 480/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0322
# Epoch 481/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0320
# Epoch 482/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0318
# Epoch 483/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 484/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0314
# Epoch 485/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0313
# Epoch 486/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0311
# Epoch 487/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0309
# Epoch 488/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0307
# Epoch 489/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0305
# Epoch 490/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0304
# Epoch 491/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 492/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 493/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0298
# Epoch 494/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0297
# Epoch 495/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0295
# Epoch 496/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 497/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0291
# Epoch 498/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0289
# Epoch 499/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 500/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 501/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0284
# Epoch 502/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 503/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0281
# Epoch 504/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0279
# Epoch 505/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0277
# Epoch 506/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 507/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0274
# Epoch 508/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0272
# Epoch 509/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0270
# Epoch 510/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0268
# Epoch 511/3000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0267
# Epoch 512/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0265
# Epoch 513/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0263
# Epoch 514/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0262
# Epoch 515/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0260
# Epoch 516/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0258
# Epoch 517/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0257
# Epoch 518/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0255
# Epoch 519/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0253
# Epoch 520/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0252
# Epoch 521/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0250
# Epoch 522/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0248
# Epoch 523/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0247
# Epoch 524/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0245
# Epoch 525/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0244
# Epoch 526/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0242
# Epoch 527/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0240
# Epoch 528/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0239
# Epoch 529/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0237
# Epoch 530/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0236
# Epoch 531/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0234
# Epoch 532/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 533/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0231
# Epoch 534/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0230
# Epoch 535/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0228
# Epoch 536/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0227
# Epoch 537/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 538/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0224
# Epoch 539/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0222
# Epoch 540/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0221
# Epoch 541/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 542/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0218
# Epoch 543/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0217
# Epoch 544/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0215
# Epoch 545/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 546/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0213
# Epoch 547/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0211
# Epoch 548/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0210
# Epoch 549/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 550/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 551/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 552/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0205
# Epoch 553/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 554/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0202
# Epoch 555/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0201
# Epoch 556/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0200
# Epoch 557/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0199
# Epoch 558/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0197
# Epoch 559/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 560/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0195
# Epoch 561/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0194
# Epoch 562/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0193
# Epoch 563/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0192
# Epoch 564/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0190
# Epoch 565/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0189
# Epoch 566/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0188
# Epoch 567/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0187
# Epoch 568/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0186
# Epoch 569/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0185
# Epoch 570/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0184
# Epoch 571/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0183
# Epoch 572/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0182
# Epoch 573/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0181
# Epoch 574/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0180
# Epoch 575/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0179
# Epoch 576/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0178
# Epoch 577/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0177
# Epoch 578/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0176
# Epoch 579/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0175
# Epoch 580/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0174
# Epoch 581/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0174
# Epoch 582/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0173
# Epoch 583/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0172
# Epoch 584/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0171
# Epoch 585/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0170
# Epoch 586/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0169
# Epoch 587/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0168
# Epoch 588/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0168
# Epoch 589/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 590/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0166
# Epoch 591/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0165
# Epoch 592/3000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0164
# Epoch 593/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0164
# Epoch 594/3000
# ...
# Epoch 2815/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3457e-04
# Epoch 2816/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3437e-04
# Epoch 2817/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3418e-04
# Epoch 2818/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3398e-04
# Epoch 2819/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3379e-04
# Epoch 2820/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3359e-04
# Epoch 2821/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3340e-04
# Epoch 2822/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3321e-04
# Epoch 2823/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3301e-04
# Epoch 2824/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3282e-04
# Epoch 2825/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3263e-04
# Epoch 2826/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3244e-04
# Epoch 2827/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3224e-04
# Epoch 2828/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3205e-04
# Epoch 2829/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3186e-04
# Epoch 2830/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3167e-04
# Epoch 2831/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3148e-04
# Epoch 2832/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3129e-04
# Epoch 2833/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3110e-04
# Epoch 2834/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3091e-04
# Epoch 2835/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3072e-04
# Epoch 2836/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3053e-04
# Epoch 2837/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3034e-04
# Epoch 2838/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3015e-04
# Epoch 2839/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2997e-04
# Epoch 2840/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2978e-04
# Epoch 2841/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2959e-04
# Epoch 2842/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2940e-04
# Epoch 2843/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2922e-04
# Epoch 2844/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2903e-04
# Epoch 2845/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2884e-04
# Epoch 2846/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2866e-04
# Epoch 2847/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2847e-04
# Epoch 2848/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2829e-04
# Epoch 2849/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2810e-04
# Epoch 2850/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2792e-04
# Epoch 2851/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2773e-04
# Epoch 2852/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2755e-04
# Epoch 2853/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2737e-04
# Epoch 2854/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2718e-04
# Epoch 2855/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2700e-04
# Epoch 2856/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2682e-04
# Epoch 2857/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2663e-04
# Epoch 2858/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2645e-04
# Epoch 2859/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2627e-04
# Epoch 2860/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2609e-04
# Epoch 2861/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2591e-04
# Epoch 2862/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2573e-04
# Epoch 2863/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2554e-04
# Epoch 2864/3000
# 1/1 [==============================] - 0s 29ms/step - loss: 2.2536e-04
# Epoch 2865/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2518e-04
# Epoch 2866/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2500e-04
# Epoch 2867/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2482e-04
# Epoch 2868/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2465e-04
# Epoch 2869/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2447e-04
# Epoch 2870/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2429e-04
# Epoch 2871/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2411e-04
# Epoch 2872/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2393e-04
# Epoch 2873/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2375e-04
# Epoch 2874/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2358e-04
# Epoch 2875/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2340e-04
# Epoch 2876/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2322e-04
# Epoch 2877/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2304e-04
# Epoch 2878/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2287e-04
# Epoch 2879/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2269e-04
# Epoch 2880/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2252e-04
# Epoch 2881/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2234e-04
# Epoch 2882/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2216e-04
# Epoch 2883/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2199e-04
# Epoch 2884/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2181e-04
# Epoch 2885/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2164e-04
# Epoch 2886/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2147e-04
# Epoch 2887/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2129e-04
# Epoch 2888/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2112e-04
# Epoch 2889/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2094e-04
# Epoch 2890/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2077e-04
# Epoch 2891/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2060e-04
# Epoch 2892/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2043e-04
# Epoch 2893/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2025e-04
# Epoch 2894/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2008e-04
# Epoch 2895/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1991e-04
# Epoch 2896/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1974e-04
# Epoch 2897/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1957e-04
# Epoch 2898/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1940e-04
# Epoch 2899/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1922e-04
# Epoch 2900/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1905e-04
# Epoch 2901/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1888e-04
# Epoch 2902/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1871e-04
# Epoch 2903/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1854e-04
# Epoch 2904/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1837e-04
# Epoch 2905/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1821e-04
# Epoch 2906/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1804e-04
# Epoch 2907/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1787e-04
# Epoch 2908/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1770e-04
# Epoch 2909/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1753e-04
# Epoch 2910/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1736e-04
# Epoch 2911/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1720e-04
# Epoch 2912/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1703e-04
# Epoch 2913/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1686e-04
# Epoch 2914/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1669e-04
# Epoch 2915/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1653e-04
# Epoch 2916/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1636e-04
# Epoch 2917/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1620e-04
# Epoch 2918/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1603e-04
# Epoch 2919/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1586e-04
# Epoch 2920/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1570e-04
# Epoch 2921/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1553e-04
# Epoch 2922/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1537e-04
# Epoch 2923/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1520e-04
# Epoch 2924/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1504e-04
# Epoch 2925/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1488e-04
# Epoch 2926/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1471e-04
# Epoch 2927/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1455e-04
# Epoch 2928/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1439e-04
# Epoch 2929/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1422e-04
# Epoch 2930/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1406e-04
# Epoch 2931/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1390e-04
# Epoch 2932/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1374e-04
# Epoch 2933/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1357e-04
# Epoch 2934/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1341e-04
# Epoch 2935/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1325e-04
# Epoch 2936/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1309e-04
# Epoch 2937/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1293e-04
# Epoch 2938/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1277e-04
# Epoch 2939/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1261e-04
# Epoch 2940/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1245e-04
# Epoch 2941/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1229e-04
# Epoch 2942/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1213e-04
# Epoch 2943/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1197e-04
# Epoch 2944/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1181e-04
# Epoch 2945/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1165e-04
# Epoch 2946/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1149e-04
# Epoch 2947/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1133e-04
# Epoch 2948/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1117e-04
# Epoch 2949/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1101e-04
# Epoch 2950/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1086e-04
# Epoch 2951/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1070e-04
# Epoch 2952/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1054e-04
# Epoch 2953/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1038e-04
# Epoch 2954/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1023e-04
# Epoch 2955/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1007e-04
# Epoch 2956/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0991e-04
# Epoch 2957/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0976e-04
# Epoch 2958/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0960e-04
# Epoch 2959/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0945e-04
# Epoch 2960/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0929e-04
# Epoch 2961/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0913e-04
# Epoch 2962/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0898e-04
# Epoch 2963/3000
# 1/1 [==============================] - 0s 16ms/step - loss: 2.0882e-04
# Epoch 2964/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0867e-04
# Epoch 2965/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0852e-04
# Epoch 2966/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0836e-04
# Epoch 2967/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0821e-04
# Epoch 2968/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0805e-04
# Epoch 2969/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0790e-04
# Epoch 2970/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0775e-04
# Epoch 2971/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0759e-04
# Epoch 2972/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0744e-04
# Epoch 2973/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0729e-04
# Epoch 2974/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0714e-04
# Epoch 2975/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0698e-04
# Epoch 2976/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0683e-04
# Epoch 2977/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0668e-04
# Epoch 2978/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0653e-04
# Epoch 2979/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0638e-04
# Epoch 2980/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0623e-04
# Epoch 2981/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0608e-04
# Epoch 2982/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0592e-04
# Epoch 2983/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0577e-04
# Epoch 2984/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0562e-04
# Epoch 2985/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0547e-04
# Epoch 2986/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0532e-04
# Epoch 2987/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0517e-04
# Epoch 2988/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0503e-04
# Epoch 2989/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0488e-04
# Epoch 2990/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0473e-04
# Epoch 2991/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0458e-04
# Epoch 2992/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0443e-04
# Epoch 2993/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0428e-04
# Epoch 2994/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0413e-04
# Epoch 2995/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0399e-04
# Epoch 2996/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0384e-04
# Epoch 2997/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0369e-04
# Epoch 2998/3000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0354e-04
# Epoch 2999/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0340e-04
# Epoch 3000/3000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0325e-04

# %%
# Compare with the now trained network
plot_BC(pb.u_exact_np,model_np)

# %%
color_plot(bc_model)

# %%
# Make the bc_model non-trianable
for layer in bc_model.layers:
    layer.trainable = False

# Display model summary after making weights non-trainable
bc_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 371 (2.90 KB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 371 (2.90 KB)
# _________________________________________________________________

# %% [markdown]
# ###  VPINN MODEL

# %%
# Create the network to be trained on the variational form
MODEL = tfk.models.Sequential()
MODEL.add(tf.keras.Input(shape=(2,),dtype=tf_type))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tf.keras.layers.Dense(1,activation='linear',kernel_initializer=initializer,dtype=tf_type,use_bias=True))

MODEL.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 50)                150
#
#  dense_6 (Dense)             (None, 50)                2550
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5301 (41.41 KB)
# Trainable params: 5301 (41.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Problem parameters

# %%
# order of test function 
N_test = 2

params = {'scheme': 'VPINNs','N_test':N_test}

# %%
# Initialise VPINN class
vp=VPINN(pb,params,mesh,True,NN=MODEL)
model=vp.u_NN_BC
vp.set_bc_model(bc_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/mariano/Documenti/progetto serio/IVPINN/absolute_madness/main.ipynb Cell 21 line 2
#       <a href='vscode-notebook-cell:/home/mariano/Documenti/progetto%20serio/IVPINN/absolute_madness/main.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> # Initialise VPINN class
# ----> <a href='vscode-notebook-cell:/home/mariano/Documenti/progetto%20serio/IVPINN/absolute_madness/main.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> vp=VPINN(pb,params,mesh,True,NN=MODEL)
#       <a href='vscode-notebook-cell:/home/mariano/Documenti/progetto%20serio/IVPINN/absolute_madness/main.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> model=vp.u_NN_BC
#       <a href='vscode-notebook-cell:/home/mariano/Documenti/progetto%20serio/IVPINN/absolute_madness/main.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> vp.set_bc_model(bc_model)
#
# NameError: name 'mesh' is not defined

# %%
vp.set_bc_model(bc_model)
color_plot(vp.NN_imposeBC)

# %%
# Start training
history=vp.train(2000,0.001,bc_model)
# Out:
# Iteration: 0 loss: 0.0018474220 time: 25.40230703353882
# Iteration: 10 loss: 0.0016860622 time: 0.0807194709777832
# Iteration: 20 loss: 0.0015391566 time: 0.07748723030090332
# Iteration: 30 loss: 0.0013834605 time: 0.08289957046508789
# Iteration: 40 loss: 0.0012552850 time: 0.08091521263122559
# Iteration: 50 loss: 0.0012147985 time: 0.07736539840698242
# Iteration: 60 loss: 0.0012106187 time: 0.08060693740844727
# Iteration: 70 loss: 0.0011932774 time: 0.07948660850524902
# Iteration: 80 loss: 0.0011755955 time: 0.07777571678161621
# Iteration: 90 loss: 0.0011485152 time: 0.07753229141235352
# Iteration: 100 loss: 0.0011024683 time: 0.07969307899475098
# Iteration: 110 loss: 0.0010254999 time: 0.10712265968322754
# Iteration: 120 loss: 0.0009167726 time: 0.10903596878051758
# Iteration: 130 loss: 0.0008191044 time: 0.11032462120056152
# Iteration: 140 loss: 0.0007823468 time: 0.10908269882202148
# Iteration: 150 loss: 0.0007648921 time: 0.10521483421325684
# Iteration: 160 loss: 0.0007517971 time: 0.10429620742797852
# Iteration: 170 loss: 0.0007434306 time: 0.10480642318725586
# Iteration: 180 loss: 0.0007350914 time: 0.10264039039611816
# Iteration: 190 loss: 0.0007266178 time: 0.1023411750793457
# Iteration: 200 loss: 0.0007174666 time: 0.10441708564758301
# Iteration: 210 loss: 0.0007071955 time: 0.1012415885925293
# Iteration: 220 loss: 0.0006956553 time: 0.1041555404663086
# Iteration: 230 loss: 0.0006829944 time: 0.10518121719360352
# Iteration: 240 loss: 0.0006697340 time: 0.10299229621887207
# Iteration: 250 loss: 0.0006566776 time: 0.10424470901489258
# Iteration: 260 loss: 0.0006445659 time: 0.10622167587280273
# Iteration: 270 loss: 0.0006336443 time: 0.10767006874084473
# Iteration: 280 loss: 0.0006236697 time: 0.10623455047607422
# Iteration: 290 loss: 0.0006145638 time: 0.103363037109375
# Iteration: 300 loss: 0.0006066320 time: 0.10368537902832031
# Iteration: 310 loss: 0.0006000749 time: 0.10507655143737793
# Iteration: 320 loss: 0.0005946898 time: 0.108123779296875
# Iteration: 330 loss: 0.0005900622 time: 0.10250091552734375
# Iteration: 340 loss: 0.0005858238 time: 0.10319328308105469
# Iteration: 350 loss: 0.0005816363 time: 0.10368585586547852
# Iteration: 360 loss: 0.0005769189 time: 0.10768485069274902
# Iteration: 370 loss: 0.0005703972 time: 0.10444331169128418
# Iteration: 380 loss: 0.0005592343 time: 0.10613155364990234
# Iteration: 390 loss: 0.0005372688 time: 0.10586261749267578
# Iteration: 400 loss: 0.0004946540 time: 0.10513448715209961
# Iteration: 410 loss: 0.0004305707 time: 0.10603857040405273
# Iteration: 420 loss: 0.0003721057 time: 0.10889148712158203
# Iteration: 430 loss: 0.0003193080 time: 0.10495305061340332
# Iteration: 440 loss: 0.0002693278 time: 0.10791015625
# Iteration: 450 loss: 0.0002335234 time: 0.1048579216003418
# Iteration: 460 loss: 0.0002030843 time: 0.11048316955566406
# Iteration: 470 loss: 0.0001740273 time: 0.10666537284851074
# Iteration: 480 loss: 0.0001521455 time: 0.10819292068481445
# Iteration: 490 loss: 0.0001374902 time: 0.10358619689941406
# Iteration: 500 loss: 0.0001259530 time: 0.10406279563903809
# Iteration: 510 loss: 0.0001156638 time: 0.11117029190063477
# Iteration: 520 loss: 0.0001072087 time: 0.10822391510009766
# Iteration: 530 loss: 0.0000998562 time: 0.11030387878417969
# Iteration: 540 loss: 0.0000933800 time: 0.1095125675201416
# Iteration: 550 loss: 0.0000877539 time: 0.10802721977233887
# Iteration: 560 loss: 0.0000828454 time: 0.11241984367370605
# Iteration: 570 loss: 0.0000785346 time: 0.1176004409790039
# Iteration: 580 loss: 0.0000747143 time: 0.14623451232910156
# Iteration: 590 loss: 0.0000712588 time: 0.11077618598937988
# Iteration: 600 loss: 0.0000680300 time: 0.1095132827758789
# Iteration: 610 loss: 0.0000649132 time: 0.10766458511352539
# Iteration: 620 loss: 0.0000618364 time: 0.1112661361694336
# Iteration: 630 loss: 0.0000587748 time: 0.11182904243469238
# Iteration: 640 loss: 0.0000557341 time: 0.1069481372833252
# Iteration: 650 loss: 0.0000527071 time: 0.10968136787414551
# Iteration: 660 loss: 0.0000496554 time: 0.11019372940063477
# Iteration: 670 loss: 0.0000465809 time: 0.11229181289672852
# Iteration: 680 loss: 0.0000436100 time: 0.13583111763000488
# Iteration: 690 loss: 0.0000409020 time: 0.13344264030456543
# Iteration: 700 loss: 0.0000384829 time: 0.11832499504089355
# Iteration: 710 loss: 0.0000362731 time: 0.1084599494934082
# Iteration: 720 loss: 0.0000342165 time: 0.1201927661895752
# Iteration: 730 loss: 0.0000322858 time: 0.11817288398742676
# Iteration: 740 loss: 0.0000304668 time: 0.12387228012084961
# Iteration: 750 loss: 0.0000287517 time: 0.1252427101135254
# Iteration: 760 loss: 0.0000271380 time: 0.1100468635559082
# Iteration: 770 loss: 0.0000256246 time: 0.10727572441101074
# Iteration: 780 loss: 0.0000242095 time: 0.11600160598754883
# Iteration: 790 loss: 0.0000228871 time: 0.13053369522094727
# Iteration: 800 loss: 0.0000216501 time: 0.11190652847290039
# Iteration: 810 loss: 0.0000204916 time: 0.10791397094726562
# Iteration: 820 loss: 0.0000194069 time: 0.1078481674194336
# Iteration: 830 loss: 0.0000183931 time: 0.10817980766296387
# Iteration: 840 loss: 0.0000174484 time: 0.10763669013977051
# Iteration: 850 loss: 0.0000165707 time: 0.1142427921295166
# Iteration: 860 loss: 0.0000157572 time: 0.12475991249084473
# Iteration: 870 loss: 0.0000150045 time: 0.1094808578491211
# Iteration: 880 loss: 0.0000143083 time: 0.12438225746154785
# Iteration: 890 loss: 0.0000136643 time: 0.11838459968566895
# Iteration: 900 loss: 0.0000130681 time: 0.11811518669128418
# Iteration: 910 loss: 0.0000125155 time: 0.10785579681396484
# Iteration: 920 loss: 0.0000120028 time: 0.10668635368347168
# Iteration: 930 loss: 0.0000115265 time: 0.10367870330810547
# Iteration: 940 loss: 0.0000110836 time: 0.10968136787414551
# Iteration: 950 loss: 0.0000106713 time: 0.1092064380645752
# Iteration: 960 loss: 0.0000102872 time: 0.11919116973876953
# Iteration: 970 loss: 0.0000099290 time: 0.11531734466552734
# Iteration: 980 loss: 0.0000095948 time: 0.10968995094299316
# Iteration: 990 loss: 0.0000092829 time: 0.11358475685119629
# Iteration: 1000 loss: 0.0000089917 time: 0.10860848426818848
# Iteration: 1010 loss: 0.0000099724 time: 0.10780954360961914
# Iteration: 1020 loss: 0.0000089893 time: 0.10707855224609375
# Iteration: 1030 loss: 0.0000084022 time: 0.11179518699645996
# Iteration: 1040 loss: 0.0000080611 time: 0.11127471923828125
# Iteration: 1050 loss: 0.0000078380 time: 0.11345529556274414
# Iteration: 1060 loss: 0.0000076471 time: 0.12308168411254883
# Iteration: 1070 loss: 0.0000074675 time: 0.11886405944824219
# Iteration: 1080 loss: 0.0000072967 time: 0.12560248374938965
# Iteration: 1090 loss: 0.0000071342 time: 0.10772109031677246
# Iteration: 1100 loss: 0.0000069793 time: 0.11281394958496094
# Iteration: 1110 loss: 0.0000068313 time: 0.16376423835754395
# Iteration: 1120 loss: 0.0000066898 time: 0.1096644401550293
# Iteration: 1130 loss: 0.0000065542 time: 0.10897350311279297
# Iteration: 1140 loss: 0.0000064243 time: 0.11093783378601074
# Iteration: 1150 loss: 0.0000062995 time: 0.1417865753173828
# Iteration: 1160 loss: 0.0000061795 time: 0.12433767318725586
# Iteration: 1170 loss: 0.0000060641 time: 0.11518001556396484
# Iteration: 1180 loss: 0.0000059531 time: 0.1100921630859375
# Iteration: 1190 loss: 0.0000058461 time: 0.11742758750915527
# Iteration: 1200 loss: 0.0000057429 time: 0.15017223358154297
# Iteration: 1210 loss: 0.0000056435 time: 0.11941313743591309
# Iteration: 1220 loss: 0.0000055475 time: 0.11116504669189453
# Iteration: 1230 loss: 0.0000054549 time: 0.1062772274017334
# Iteration: 1240 loss: 0.0000053656 time: 0.12343025207519531
# Iteration: 1250 loss: 0.0000052793 time: 0.1308307647705078
# Iteration: 1260 loss: 0.0000051960 time: 0.11536264419555664
# Iteration: 1270 loss: 0.0000051155 time: 0.10868000984191895
# Iteration: 1280 loss: 0.0000050378 time: 0.11248373985290527
# Iteration: 1290 loss: 0.0000049627 time: 0.1382913589477539
# Iteration: 1300 loss: 0.0000048901 time: 0.14346885681152344
# Iteration: 1310 loss: 0.0000048200 time: 0.113494873046875
# Iteration: 1320 loss: 0.0000047522 time: 0.10895562171936035
# Iteration: 1330 loss: 0.0000046867 time: 0.11739134788513184
# Iteration: 1340 loss: 0.0000046233 time: 0.13496804237365723
# Iteration: 1350 loss: 0.0000045620 time: 0.12104177474975586
# Iteration: 1360 loss: 0.0000045027 time: 0.1197049617767334
# Iteration: 1370 loss: 0.0000044455 time: 0.11168193817138672
# Iteration: 1380 loss: 0.0000047190 time: 0.10955381393432617
# Iteration: 1390 loss: 0.0000045123 time: 0.11017322540283203
# Iteration: 1400 loss: 0.0000043732 time: 0.110198974609375
# Iteration: 1410 loss: 0.0000042672 time: 0.1082756519317627
# Iteration: 1420 loss: 0.0000041975 time: 0.10400390625
# Iteration: 1430 loss: 0.0000041458 time: 0.1082613468170166
# Iteration: 1440 loss: 0.0000041016 time: 0.11857843399047852
# Iteration: 1450 loss: 0.0000040580 time: 0.10731625556945801
# Iteration: 1460 loss: 0.0000040156 time: 0.10936307907104492
# Iteration: 1470 loss: 0.0000039748 time: 0.10750222206115723
# Iteration: 1480 loss: 0.0000039351 time: 0.10799145698547363
# Iteration: 1490 loss: 0.0000038964 time: 0.1123199462890625
# Iteration: 1500 loss: 0.0000038588 time: 0.11018538475036621
# Iteration: 1510 loss: 0.0000038222 time: 0.10680603981018066
# Iteration: 1520 loss: 0.0000037865 time: 0.10560798645019531
# Iteration: 1530 loss: 0.0000037517 time: 0.10931897163391113
# Iteration: 1540 loss: 0.0000037177 time: 0.10804033279418945
# Iteration: 1550 loss: 0.0000036846 time: 0.10811948776245117
# Iteration: 1560 loss: 0.0000036522 time: 0.10976386070251465
# Iteration: 1570 loss: 0.0000036206 time: 0.10621833801269531
# Iteration: 1580 loss: 0.0000035939 time: 0.11069917678833008
# Iteration: 1590 loss: 0.0000043506 time: 0.13229918479919434
# Iteration: 1600 loss: 0.0000035338 time: 0.12215399742126465
# Iteration: 1610 loss: 0.0000035127 time: 0.1140139102935791
# Iteration: 1620 loss: 0.0000034793 time: 0.10808396339416504
# Iteration: 1630 loss: 0.0000034515 time: 0.1101539134979248
# Iteration: 1640 loss: 0.0000034244 time: 0.10939526557922363
# Iteration: 1650 loss: 0.0000033978 time: 0.11962056159973145
# Iteration: 1660 loss: 0.0000033712 time: 0.11716747283935547
# Iteration: 1670 loss: 0.0000033456 time: 0.11763668060302734
# Iteration: 1680 loss: 0.0000033209 time: 0.10903167724609375
# Iteration: 1690 loss: 0.0000032966 time: 0.1106724739074707
# Iteration: 1700 loss: 0.0000032726 time: 0.12331008911132812
# Iteration: 1710 loss: 0.0000032490 time: 0.1214897632598877
# Iteration: 1720 loss: 0.0000032258 time: 0.12091183662414551
# Iteration: 1730 loss: 0.0000032028 time: 0.11277484893798828
# Iteration: 1740 loss: 0.0000031802 time: 0.10654497146606445
# Iteration: 1750 loss: 0.0000031579 time: 0.11078310012817383
# Iteration: 1760 loss: 0.0000031359 time: 0.10780739784240723
# Iteration: 1770 loss: 0.0000031142 time: 0.11600279808044434
# Iteration: 1780 loss: 0.0000030927 time: 0.12391018867492676
# Iteration: 1790 loss: 0.0000030716 time: 0.11729860305786133
# Iteration: 1800 loss: 0.0000030506 time: 0.11247110366821289
# Iteration: 1810 loss: 0.0000030300 time: 0.10521769523620605
# Iteration: 1820 loss: 0.0000030096 time: 0.1065366268157959
# Iteration: 1830 loss: 0.0000030081 time: 0.11253619194030762
# Iteration: 1840 loss: 0.0000035318 time: 0.10957098007202148
# Iteration: 1850 loss: 0.0000032165 time: 0.10712170600891113
# Iteration: 1860 loss: 0.0000029750 time: 0.1040186882019043
# Iteration: 1870 loss: 0.0000029202 time: 0.10951566696166992
# Iteration: 1880 loss: 0.0000028992 time: 0.10838675498962402
# Iteration: 1890 loss: 0.0000028786 time: 0.10793709754943848
# Iteration: 1900 loss: 0.0000028604 time: 0.10587024688720703
# Iteration: 1910 loss: 0.0000028426 time: 0.11197543144226074
# Iteration: 1920 loss: 0.0000028250 time: 0.10769057273864746
# Iteration: 1930 loss: 0.0000028077 time: 0.10501360893249512
# Iteration: 1940 loss: 0.0000027906 time: 0.10662031173706055
# Iteration: 1950 loss: 0.0000027736 time: 0.10892534255981445
# Iteration: 1960 loss: 0.0000027567 time: 0.10587406158447266
# Iteration: 1970 loss: 0.0000027400 time: 0.11100387573242188
# Iteration: 1980 loss: 0.0000027235 time: 0.10930895805358887
# Iteration: 1990 loss: 0.0000027071 time: 0.10715818405151367
# Iteration: 2000 loss: 0.0000026909 time: 0.10824775695800781

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Loss

# %%
def plot_loss(history):  
    iterations = range(0, len(history) * 10, 10)  # Assuming losses are provided every 10 iterations

    plt.figure(figsize=(10, 10))

    plt.subplot(211)
    plt.plot(iterations, history, marker='*',color='green',linewidth=1)
    plt.title('Loss Function Over Iterations')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.grid()

    plt.subplot(212)
    plt.semilogy(iterations, history,linewidth=1)
    plt.title('Loss Function Over Iterations (semilog scale)')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.grid()

# %%
plot_loss(history)

# %% [markdown]
# ### Prediction

# %%
plot_BC(pb.u_exact_np,vp.u_NN_BC)

# %%
color_plot(vp.NN_imposeBC)

# %% [markdown]
# ### Residuals

# %%
# Find the residuals over vertices and edges
if N_test == 1:
    residual_ending_vertices = vp.calc_residuals()   # r = 1 case
    vp.residual_summary(residual_ending_vertices)   # r = 1 case
elif N_test == 2:
    residual_ending_vertices, residual_ending_edges = vp.calc_residuals()  # r = 2
    vp.residual_summary(residual_ending_vertices,residual_ending_edges)  # r = 2
# Out:
# residual of vertices :
# -->max  =  0.0001552686906787108
# -->min  =  3.802920282492395e-12
# -->mean =  5.183772142993419e-06
# residual of edges :
# -->max  =  2.1710594886166065e-05
# -->min  =  3.178955715952418e-12
# -->mean =  1.93970633418584e-06

# %%
x = vp.mesh['vertices'][:,0]
y = vp.mesh['vertices'][:,1]

plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.triplot(
    x,
    y, color='lightgrey'
)
scatter = plt.scatter(x, y, c=residual_ending_vertices, cmap='viridis', marker='o')

plt.colorbar(scatter, label='Function Value')
plt.title('Heatmap from Point Evaluations')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

import scipy.interpolate as sp

f = sp.interp2d(x, y, residual_ending_vertices, kind="linear")

# from pylab import figure, cm
from matplotlib.colors import LogNorm

x_coords = np.linspace(0, 1, 20)
z_coords = np.linspace(0, 1, 20)
c_i = np.abs(f(x_coords, z_coords))

plt.subplot(122)
fig = plt.imshow(
    c_i,
    extent=[min(x), max(x), min(y), max(y)],
    origin="lower",
    interpolation="bicubic",
    # norm=LogNorm(vmin = np.min(c_i), vmax=np.max(c_i))
)
plt.title('Interpolated residual heatmap')
plt.scatter(x, y, color='lightgrey', marker='+')
plt.colorbar(fig)
# Out:
# /tmp/ipykernel_4564/659253298.py:20: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   f = sp.interp2d(x, y, residual_ending_vertices, kind="linear")
# /home/mariano/Documenti/test/base/lib/python3.9/site-packages/scipy/interpolate/_fitpack_impl.py:593: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=13,11 m=88 fp=0.000000 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# /tmp/ipykernel_4564/659253298.py:27: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   c_i = np.abs(f(x_coords, z_coords))

# %% [markdown]
# ### H1 and L2 error

# %%
# Get quad pairs
from numpy.polynomial import legendre


def get_quad_rule(n: int):
    # Degree of the Legendre polynomial (number of nodes - 1)

    # Nodes and weights for Gauss-Legendre quadrature
    nodes, weights = legendre.leggauss(n + 1)



    nodes=(nodes+1.0)/2.0


    # Nodes=np.array([nodes],dtype=np_type)

    Weights=np.array([weights],dtype=np_type)
    w = Weights.T @ Weights
    w = np.reshape(w, (-1,1))


    x, y =np.meshgrid(nodes,nodes)


    x = x.flatten()
    y = y.flatten()
 



    xy=np.array([x,y]).T


    return xy, w/4

# %%
def L2_error(xy, w):
    
    u_NN = vp.NN_imposeBC(xy)

    # Find the exact solution
    u_ex = pb.u_exact_np(xy[:,0], xy[:,1])
    u_ex = np.reshape(u_ex, (-1,1))

    integrand = (u_ex - u_NN)**2


    # Find the difference between exact and NN 
    # return (u_ex - u_NN)**2

    return np.sqrt(np.sum(w*integrand))



def semi_H1_error(xy, w):

    # Find the gradient of the exact solution
    grad_ex = np.array([pb.dudx(xy[:,0], xy[:,1]), pb.dudy(xy[:,0], xy[:,1])],dtype=np_type).T


    # Find the gradient of the NN solution
    grad_NN = vp.eval_grad_NN_BC(tf.constant(xy, dtype=tf_type))

    


    # Find the difference between exact and NN 
    pw_diff = grad_ex - grad_NN

    pw_diff = pw_diff*pw_diff


    # Return dx_error^2 + dy_error^2
    return np.sqrt(np.sum(np.sum(pw_diff,axis=1)*w))

# %% [markdown]
# ### NETWORKS WITH EXACT BC

# %%
import os;
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import importlib

import VPINN_tri_final as VPINN_tri_final

import interpolator as interpolator

importlib.reload(VPINN_tri_final)

importlib.reload(interpolator)

from VPINN_tri_final import *
from interpolator import *

from MeshLib import MeshLib as ml


import PROBDEF
# Out:
# interpolator_lib imported

# %%
# seed for reproducibility
initializer = tf.keras.initializers.GlorotUniform(seed=100)


# mesh init
domain = ((0, 0), (1, 0), (1, 1), (0, 1))
#mesh = generate_mesh(domain, 0.01)

# %%
def plot_BC(u_exact, u_NN_BC_):
    """both numpy functions"""
    x = np.linspace(0, 1, 200, dtype=np.float64)

    eval_exact = [u_exact(x[i], 1.0) for i in range(len(x))]

    eval_net = [u_NN_BC_(x[i], 1.0) for i in range(len(x))]

    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    plt.figure(figsize=(10,7))  # Set the figure size

    # Plot the data
    plt.subplot(221)   
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("top edge")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.0) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.0) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(223)    
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("bottom edge")
    plt.legend()

    eval_exact = [u_exact(1.0, x[i]) for i in range(len(x))]
    eval_net = [u_NN_BC_(1.0, x[i]) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(222)    
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("right edge")
    plt.legend()

    eval_exact = [u_exact(0.0, x[i]) for i in range(len(x))]
    eval_net = [u_NN_BC_(0.0, x[i]) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(224)   
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("left edge")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.5) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.5) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    plt.figure(figsize=(10, 7))  # Set the figure size

    # Plot the data
    plt.subplot(221)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle y=0.5")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.25) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.25) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(222)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle y=0.25")
    plt.legend()

    eval_exact = [u_exact(x[i], 0.75) for i in range(len(x))]
    eval_net = [u_NN_BC_(x[i], 0.75) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(223)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle y=0.75")
    plt.legend()

    eval_exact = [u_exact(0.5, x[i]) for i in range(len(x))]
    eval_net = [u_NN_BC_(0.5, x[i]) for i in range(len(x))]
    eval_exact = np.array(eval_exact)
    eval_net = np.array(eval_net)

    # plt.figure(figsize=(8, 6))  # Set the figure size

    # Plot the data
    plt.subplot(224)
    plt.plot(x, eval_net, label="eval_net", linestyle="-", marker="o", color="b", markersize=2)
    plt.plot(x, eval_exact, label="eval_exact", linestyle="--", marker="x", color="r", markersize=2)
    plt.grid()
    plt.title("slice in the middle x=0.50")
    plt.legend()

def helper_colour_plot(x, y, model):

    x_=tf.reshape(x,(-1,1))
    y_=tf.reshape(y,(-1,1))

    eval=tf.concat([x_,y_],axis=1)

    return tf.reshape(model(eval),(tf.shape(x)[0],-1))

def color_plot(model):

    x = np.linspace(0, 1, 1000)
    y = np.linspace(0, 1, 1000)

    X, Y = np.meshgrid(x, y)

    error = np.abs(pb.u_exact_np(X,Y)-helper_colour_plot(X,Y,model))

    fig=plt.imshow(
        error,
        extent=[min(x), max(x), min(y), max(y)],
        vmin=np.min(error),
        vmax=np.max(error)
    )

    plt.title('Error Map')
    plt.colorbar(fig)

    fig.axes.set_autoscale_on(False)

# %%
MODEL = tfk.models.Sequential()
MODEL.add(tf.keras.Input(shape=(2,),dtype=tf_type))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
MODEL.add(tf.keras.layers.Dense(1,activation='linear',kernel_initializer=initializer,dtype=tf_type,use_bias=True))

MODEL.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_74 (Dense)            (None, 50)                150
#
#  dense_75 (Dense)            (None, 50)                2550
#
#  dense_76 (Dense)            (None, 50)                2550
#
#  dense_77 (Dense)            (None, 50)                2550
#
#  dense_78 (Dense)            (None, 50)                2550
#
#  dense_79 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 10,401
# Trainable params: 10,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
mesh_chain = ml.generate_regular_mesh_chain(domain, depth=12, plot=False)
index=2
di = 5

ml.compare(mesh_chain[index], mesh_chain[index+di],False)

print('ratio = ',mesh_chain[index].h_max /mesh_chain[index+di].h_max)
print('h = ',mesh_chain[index+di].h_max)
# Out:
# ratio =  8.0
# h =  0.08838834764831845

# %%
coarse_mesh = mesh_chain[index]
fine_mesh = mesh_chain[index+di]

# %%
print(coarse_mesh.h_max)
# Out:
# 1.4142135623730951

# %%
N_test = 2
r_interpoaltion= 5

params = {'scheme': 'VPINNs','N_test':N_test,'r_interpolation':r_interpoaltion}
# importing probdef 
pb = PROBDEF.PROBDEF()
vp=VPINN(pb,params,fine_mesh,False,coarse_mesh,MODEL)
model=vp.u_NN_BC
# Out:
# -->mesh :
#      n_triangles :  128
#      n_vertices  :  81
#      n_edges     :  208
#      h_max           :  0.1767766952966369
#      h_min           :  0.125
# -->test_fun      :
#      order       :  2
#      dof         :  225

# %%
# vp.helper()
# print(vp.x_to_eval_global)

# %%
# tf.reshape(vp.x_to_eval_global, (-1,2))

# %%
coarse_mesh.plot(triangles=[0,1])
print(list(range(5,6)))
# Out:
# [5]

# %%
vp.set_bc_model(vp.standard_bc)

# %%
color_plot(vp.NN_imposeBC)

# %%
# helper function to treat the net as a lamda function
def model_np(x, y):
    eval = tf.constant([[x, y]], dtype=tf.float64)
    return model(eval).numpy()[0, 0]


model =vp.NN_imposeBC

plot_BC(pb.u_exact_np,model_np)

# %%
vp.helper()


vp.custom_loss_IVPINN()

# print(np.shape())
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.0001628455828871583>

# %%
history=vp.train(3000,0.001)
# Out:
# Iteration: 0 loss: 0.0001628456 time: 103.1940758228302
# Iteration: 10 loss: 0.0000946721 time: 0.25382208824157715
# Iteration: 20 loss: 0.0000750626 time: 0.14017009735107422
# Iteration: 30 loss: 0.0000691412 time: 0.13009929656982422
# Iteration: 40 loss: 0.0000690709 time: 0.16609477996826172
# Iteration: 50 loss: 0.0000681584 time: 0.1408395767211914
# Iteration: 60 loss: 0.0000678157 time: 0.13112282752990723
# Iteration: 70 loss: 0.0000673322 time: 0.15650415420532227
# Iteration: 80 loss: 0.0000668401 time: 0.1358342170715332
# Iteration: 90 loss: 0.0000662258 time: 0.13692569732666016
# Iteration: 100 loss: 0.0000654636 time: 0.11518073081970215
# Iteration: 110 loss: 0.0000644654 time: 0.11480093002319336
# Iteration: 120 loss: 0.0000631709 time: 0.12301278114318848
# Iteration: 130 loss: 0.0000615822 time: 0.10833930969238281
# Iteration: 140 loss: 0.0000599741 time: 0.11042547225952148
# Iteration: 150 loss: 0.0000589387 time: 0.13942885398864746
# Iteration: 160 loss: 0.0000584001 time: 0.15029120445251465
# Iteration: 170 loss: 0.0000577994 time: 0.13054704666137695
# Iteration: 180 loss: 0.0000572309 time: 0.11287713050842285
# Iteration: 190 loss: 0.0000566846 time: 0.10125446319580078
# Iteration: 200 loss: 0.0000561246 time: 0.10238814353942871
# Iteration: 210 loss: 0.0000555425 time: 0.1100165843963623
# Iteration: 220 loss: 0.0000549328 time: 0.14846491813659668
# Iteration: 230 loss: 0.0000542893 time: 0.139570951461792
# Iteration: 240 loss: 0.0000536067 time: 0.10971617698669434
# Iteration: 250 loss: 0.0000528783 time: 0.11023139953613281
# Iteration: 260 loss: 0.0000520963 time: 0.12221598625183105
# Iteration: 270 loss: 0.0000512564 time: 0.11115550994873047
# Iteration: 280 loss: 0.0000503655 time: 0.11502385139465332
# Iteration: 290 loss: 0.0000494482 time: 0.1449906826019287
# Iteration: 300 loss: 0.0000485322 time: 0.13593268394470215
# Iteration: 310 loss: 0.0000476103 time: 0.13177895545959473
# Iteration: 320 loss: 0.0000466296 time: 0.10531425476074219
# Iteration: 330 loss: 0.0000455394 time: 0.11054182052612305
# Iteration: 340 loss: 0.0000443341 time: 0.1084604263305664
# Iteration: 350 loss: 0.0000430734 time: 0.10327339172363281
# Iteration: 360 loss: 0.0000418987 time: 0.11002111434936523
# Iteration: 370 loss: 0.0000408918 time: 0.1050577163696289
# Iteration: 380 loss: 0.0000399665 time: 0.10877680778503418
# Iteration: 390 loss: 0.0000391246 time: 0.1089329719543457
# Iteration: 400 loss: 0.0000394232 time: 0.1115562915802002
# Iteration: 410 loss: 0.0000385221 time: 0.11174488067626953
# Iteration: 420 loss: 0.0000373114 time: 0.10467672348022461
# Iteration: 430 loss: 0.0000368161 time: 0.12041115760803223
# Iteration: 440 loss: 0.0000364037 time: 0.15566396713256836
# Iteration: 450 loss: 0.0000359431 time: 0.13467645645141602
# Iteration: 460 loss: 0.0000355504 time: 0.11044669151306152
# Iteration: 470 loss: 0.0000351547 time: 0.12626266479492188
# Iteration: 480 loss: 0.0000347558 time: 0.10312986373901367
# Iteration: 490 loss: 0.0000343398 time: 0.10628986358642578
# Iteration: 500 loss: 0.0000339131 time: 0.10427474975585938
# Iteration: 510 loss: 0.0000334951 time: 0.10786056518554688
# Iteration: 520 loss: 0.0000331092 time: 0.11494803428649902
# Iteration: 530 loss: 0.0000327701 time: 0.10546755790710449
# Iteration: 540 loss: 0.0000324802 time: 0.10641098022460938
# Iteration: 550 loss: 0.0000322346 time: 0.10472655296325684
# Iteration: 560 loss: 0.0000320254 time: 0.11269783973693848
# Iteration: 570 loss: 0.0000318444 time: 0.11384749412536621
# Iteration: 580 loss: 0.0000316843 time: 0.11518597602844238
# Iteration: 590 loss: 0.0000315396 time: 0.11449432373046875
# Iteration: 600 loss: 0.0000324762 time: 0.11713433265686035
# Iteration: 610 loss: 0.0000314506 time: 0.11877202987670898
# Iteration: 620 loss: 0.0000313594 time: 0.11156034469604492
# Iteration: 630 loss: 0.0000312100 time: 0.1078331470489502
# Iteration: 640 loss: 0.0000310743 time: 0.10922694206237793
# Iteration: 650 loss: 0.0000309711 time: 0.10409235954284668
# Iteration: 660 loss: 0.0000308688 time: 0.10271286964416504
# Iteration: 670 loss: 0.0000307724 time: 0.10462021827697754
# Iteration: 680 loss: 0.0000306939 time: 0.11250162124633789
# Iteration: 690 loss: 0.0000314450 time: 0.10864901542663574
# Iteration: 700 loss: 0.0000308040 time: 0.10309004783630371
# Iteration: 710 loss: 0.0000304852 time: 0.10322237014770508
# Iteration: 720 loss: 0.0000304054 time: 0.11448502540588379
# Iteration: 730 loss: 0.0000303018 time: 0.10756158828735352
# Iteration: 740 loss: 0.0000301895 time: 0.11139941215515137
# Iteration: 750 loss: 0.0000300862 time: 0.10740971565246582
# Iteration: 760 loss: 0.0000299860 time: 0.1112825870513916
# Iteration: 770 loss: 0.0000298889 time: 0.10738611221313477
# Iteration: 780 loss: 0.0000297923 time: 0.11321449279785156
# Iteration: 790 loss: 0.0000296959 time: 0.10838007926940918
# Iteration: 800 loss: 0.0000295992 time: 0.10659503936767578
# Iteration: 810 loss: 0.0000295022 time: 0.11181306838989258
# Iteration: 820 loss: 0.0000294051 time: 0.12082195281982422
# Iteration: 830 loss: 0.0000293082 time: 0.1113729476928711
# Iteration: 840 loss: 0.0000292121 time: 0.10294699668884277
# Iteration: 850 loss: 0.0000291175 time: 0.11043334007263184
# Iteration: 860 loss: 0.0000290254 time: 0.10552167892456055
# Iteration: 870 loss: 0.0000289366 time: 0.10387372970581055
# Iteration: 880 loss: 0.0000288521 time: 0.10606002807617188
# Iteration: 890 loss: 0.0000287991 time: 0.10442495346069336
# Iteration: 900 loss: 0.0000287074 time: 0.10720658302307129
# Iteration: 910 loss: 0.0000286762 time: 0.10086917877197266
# Iteration: 920 loss: 0.0000285908 time: 0.11309170722961426
# Iteration: 930 loss: 0.0000285332 time: 0.10384988784790039
# Iteration: 940 loss: 0.0000284753 time: 0.10754728317260742
# Iteration: 950 loss: 0.0000284291 time: 0.10677909851074219
# Iteration: 960 loss: 0.0000283863 time: 0.1094214916229248
# Iteration: 970 loss: 0.0000283465 time: 0.10253310203552246
# Iteration: 980 loss: 0.0000283098 time: 0.11197495460510254
# Iteration: 990 loss: 0.0000282756 time: 0.10635232925415039
# Iteration: 1000 loss: 0.0000282437 time: 0.10680437088012695
# Iteration: 1010 loss: 0.0000282138 time: 0.10509514808654785
# Iteration: 1020 loss: 0.0000281855 time: 0.1385512351989746
# Iteration: 1030 loss: 0.0000281585 time: 0.13239264488220215
# Iteration: 1040 loss: 0.0000281327 time: 0.11313176155090332
# Iteration: 1050 loss: 0.0000281080 time: 0.10106492042541504
# Iteration: 1060 loss: 0.0000282759 time: 0.11250019073486328
# Iteration: 1070 loss: 0.0000281213 time: 0.10926270484924316
# Iteration: 1080 loss: 0.0000280615 time: 0.1084597110748291
# Iteration: 1090 loss: 0.0000280260 time: 0.10983991622924805
# Iteration: 1100 loss: 0.0000279982 time: 0.10752749443054199
# Iteration: 1110 loss: 0.0000279776 time: 0.10920214653015137
# Iteration: 1120 loss: 0.0000279549 time: 0.11152362823486328
# Iteration: 1130 loss: 0.0000279324 time: 0.10644960403442383
# Iteration: 1140 loss: 0.0000279128 time: 0.10823965072631836
# Iteration: 1150 loss: 0.0000281800 time: 0.10759305953979492
# Iteration: 1160 loss: 0.0000279660 time: 0.11099576950073242
# Iteration: 1170 loss: 0.0000278675 time: 0.10798954963684082
# Iteration: 1180 loss: 0.0000278220 time: 0.10928177833557129
# Iteration: 1190 loss: 0.0000277959 time: 0.10518884658813477
# Iteration: 1200 loss: 0.0000277704 time: 0.12958240509033203
# Iteration: 1210 loss: 0.0000277439 time: 0.10997653007507324
# Iteration: 1220 loss: 0.0000277166 time: 0.10558652877807617
# Iteration: 1230 loss: 0.0000277125 time: 0.09839510917663574
# Iteration: 1240 loss: 0.0000277239 time: 0.10496950149536133
# Iteration: 1250 loss: 0.0000276998 time: 0.10183858871459961
# Iteration: 1260 loss: 0.0000276176 time: 0.10433101654052734
# Iteration: 1270 loss: 0.0000275676 time: 0.10239934921264648
# Iteration: 1280 loss: 0.0000275326 time: 0.11060404777526855
# Iteration: 1290 loss: 0.0000274929 time: 0.10207962989807129
# Iteration: 1300 loss: 0.0000274544 time: 0.11904001235961914
# Iteration: 1310 loss: 0.0000274151 time: 0.10537242889404297
# Iteration: 1320 loss: 0.0000273744 time: 0.10954117774963379
# Iteration: 1330 loss: 0.0000273339 time: 0.10721325874328613
# Iteration: 1340 loss: 0.0000275459 time: 0.1091928482055664
# Iteration: 1350 loss: 0.0000273814 time: 0.10257244110107422
# Iteration: 1360 loss: 0.0000272336 time: 0.10783696174621582
# Iteration: 1370 loss: 0.0000271808 time: 0.10325145721435547
# Iteration: 1380 loss: 0.0000271365 time: 0.10542511940002441
# Iteration: 1390 loss: 0.0000270951 time: 0.11433529853820801
# Iteration: 1400 loss: 0.0000270552 time: 0.11626672744750977
# Iteration: 1410 loss: 0.0000270191 time: 0.1068570613861084
# Iteration: 1420 loss: 0.0000269850 time: 0.1026613712310791
# Iteration: 1430 loss: 0.0000269907 time: 0.10534286499023438
# Iteration: 1440 loss: 0.0000270871 time: 0.10798120498657227
# Iteration: 1450 loss: 0.0000270240 time: 0.10128951072692871
# Iteration: 1460 loss: 0.0000268802 time: 0.13289332389831543
# Iteration: 1470 loss: 0.0000268652 time: 0.1405928134918213
# Iteration: 1480 loss: 0.0000268282 time: 0.11989903450012207
# Iteration: 1490 loss: 0.0000268036 time: 0.12886524200439453
# Iteration: 1500 loss: 0.0000267816 time: 0.11840200424194336
# Iteration: 1510 loss: 0.0000267599 time: 0.10905957221984863
# Iteration: 1520 loss: 0.0000267865 time: 0.1077117919921875
# Iteration: 1530 loss: 0.0000272799 time: 0.09970474243164062
# Iteration: 1540 loss: 0.0000269358 time: 0.10104560852050781
# Iteration: 1550 loss: 0.0000267283 time: 0.09984803199768066
# Iteration: 1560 loss: 0.0000267104 time: 0.1030130386352539
# Iteration: 1570 loss: 0.0000266944 time: 0.09964919090270996
# Iteration: 1580 loss: 0.0000266653 time: 0.11933469772338867
# Iteration: 1590 loss: 0.0000266490 time: 0.11794781684875488
# Iteration: 1600 loss: 0.0000266324 time: 0.10966610908508301
# Iteration: 1610 loss: 0.0000266182 time: 0.11307907104492188
# Iteration: 1620 loss: 0.0000266048 time: 0.11432957649230957
# Iteration: 1630 loss: 0.0000265922 time: 0.10274934768676758
# Iteration: 1640 loss: 0.0000265803 time: 0.09704804420471191
# Iteration: 1650 loss: 0.0000265689 time: 0.11417293548583984
# Iteration: 1660 loss: 0.0000265582 time: 0.1151425838470459
# Iteration: 1670 loss: 0.0000265481 time: 0.11014723777770996
# Iteration: 1680 loss: 0.0000268151 time: 0.10822701454162598
# Iteration: 1690 loss: 0.0000270813 time: 0.12366843223571777
# Iteration: 1700 loss: 0.0000266883 time: 0.11978912353515625
# Iteration: 1710 loss: 0.0000265945 time: 0.13828659057617188
# Iteration: 1720 loss: 0.0000265491 time: 0.11482858657836914
# Iteration: 1730 loss: 0.0000265272 time: 0.10171175003051758
# Iteration: 1740 loss: 0.0000265132 time: 0.10481500625610352
# Iteration: 1750 loss: 0.0000265023 time: 0.10580015182495117
# Iteration: 1760 loss: 0.0000264946 time: 0.12161827087402344
# Iteration: 1770 loss: 0.0000264871 time: 0.12512588500976562
# Iteration: 1780 loss: 0.0000264803 time: 0.11654019355773926
# Iteration: 1790 loss: 0.0000264739 time: 0.11734914779663086
# Iteration: 1800 loss: 0.0000264678 time: 0.10143828392028809
# Iteration: 1810 loss: 0.0000264621 time: 0.1030275821685791
# Iteration: 1820 loss: 0.0000264566 time: 0.1024627685546875
# Iteration: 1830 loss: 0.0000264515 time: 0.10408973693847656
# Iteration: 1840 loss: 0.0000264465 time: 0.10602211952209473
# Iteration: 1850 loss: 0.0000264418 time: 0.1087636947631836
# Iteration: 1860 loss: 0.0000264373 time: 0.1065819263458252
# Iteration: 1870 loss: 0.0000264330 time: 0.10498976707458496
# Iteration: 1880 loss: 0.0000264289 time: 0.10061478614807129
# Iteration: 1890 loss: 0.0000264250 time: 0.10547018051147461
# Iteration: 1900 loss: 0.0000269238 time: 0.10872912406921387
# Iteration: 1910 loss: 0.0000264934 time: 0.10388565063476562
# Iteration: 1920 loss: 0.0000265642 time: 0.10823178291320801
# Iteration: 1930 loss: 0.0000264665 time: 0.10244393348693848
# Iteration: 1940 loss: 0.0000264438 time: 0.12272262573242188
# Iteration: 1950 loss: 0.0000264247 time: 0.10004591941833496
# Iteration: 1960 loss: 0.0000264143 time: 0.12937068939208984
# Iteration: 1970 loss: 0.0000264098 time: 0.11339187622070312
# Iteration: 1980 loss: 0.0000264051 time: 0.12803888320922852
# Iteration: 1990 loss: 0.0000264014 time: 0.11190342903137207
# Iteration: 2000 loss: 0.0000263981 time: 0.1187734603881836
# Iteration: 2010 loss: 0.0000263950 time: 0.1183631420135498
# Iteration: 2020 loss: 0.0000263921 time: 0.11205077171325684
# Iteration: 2030 loss: 0.0000263894 time: 0.12068319320678711
# Iteration: 2040 loss: 0.0000263868 time: 0.1002044677734375
# Iteration: 2050 loss: 0.0000263843 time: 0.1218404769897461
# Iteration: 2060 loss: 0.0000263819 time: 0.12968134880065918
# Iteration: 2070 loss: 0.0000263797 time: 0.1251239776611328
# Iteration: 2080 loss: 0.0000263775 time: 0.1173715591430664
# Iteration: 2090 loss: 0.0000263755 time: 0.13214707374572754
# Iteration: 2100 loss: 0.0000263735 time: 0.12653040885925293
# Iteration: 2110 loss: 0.0000263717 time: 0.13902997970581055
# Iteration: 2120 loss: 0.0000263699 time: 0.1017613410949707
# Iteration: 2130 loss: 0.0000263682 time: 0.11224913597106934
# Iteration: 2140 loss: 0.0000263665 time: 0.12450194358825684
# Iteration: 2150 loss: 0.0000263649 time: 0.11424112319946289
# Iteration: 2160 loss: 0.0000263634 time: 0.10501670837402344
# Iteration: 2170 loss: 0.0000263619 time: 0.10323810577392578
# Iteration: 2180 loss: 0.0000263605 time: 0.10717439651489258
# Iteration: 2190 loss: 0.0000263592 time: 0.11421370506286621
# Iteration: 2200 loss: 0.0000263579 time: 0.1165609359741211
# Iteration: 2210 loss: 0.0000263566 time: 0.11588335037231445
# Iteration: 2220 loss: 0.0000263554 time: 0.10751461982727051
# Iteration: 2230 loss: 0.0000263542 time: 0.10962939262390137
# Iteration: 2240 loss: 0.0000263530 time: 0.10510373115539551
# Iteration: 2250 loss: 0.0000263519 time: 0.13551640510559082
# Iteration: 2260 loss: 0.0000263508 time: 0.139664888381958
# Iteration: 2270 loss: 0.0000263498 time: 0.12473130226135254
# Iteration: 2280 loss: 0.0000263663 time: 0.10915422439575195
# Iteration: 2290 loss: 0.0000271285 time: 0.12395286560058594
# Iteration: 2300 loss: 0.0000266604 time: 0.11248111724853516
# Iteration: 2310 loss: 0.0000264398 time: 0.11113905906677246
# Iteration: 2320 loss: 0.0000264516 time: 0.11620664596557617
# Iteration: 2330 loss: 0.0000263902 time: 0.1041707992553711
# Iteration: 2340 loss: 0.0000263609 time: 0.1123969554901123
# Iteration: 2350 loss: 0.0000263574 time: 0.1207728385925293
# Iteration: 2360 loss: 0.0000263530 time: 0.11223745346069336
# Iteration: 2370 loss: 0.0000263504 time: 0.10654354095458984
# Iteration: 2380 loss: 0.0000263487 time: 0.11503815650939941
# Iteration: 2390 loss: 0.0000263475 time: 0.10214924812316895
# Iteration: 2400 loss: 0.0000263464 time: 0.12114977836608887
# Iteration: 2410 loss: 0.0000263454 time: 0.11759638786315918
# Iteration: 2420 loss: 0.0000263445 time: 0.11195802688598633
# Iteration: 2430 loss: 0.0000263436 time: 0.12285876274108887
# Iteration: 2440 loss: 0.0000263427 time: 0.10898137092590332
# Iteration: 2450 loss: 0.0000263419 time: 0.10575008392333984
# Iteration: 2460 loss: 0.0000263411 time: 0.1148221492767334
# Iteration: 2470 loss: 0.0000263403 time: 0.10939812660217285
# Iteration: 2480 loss: 0.0000263395 time: 0.10882186889648438
# Iteration: 2490 loss: 0.0000263387 time: 0.1045992374420166
# Iteration: 2500 loss: 0.0000263379 time: 0.14889168739318848
# Iteration: 2510 loss: 0.0000263372 time: 0.1619873046875
# Iteration: 2520 loss: 0.0000263365 time: 0.12854623794555664
# Iteration: 2530 loss: 0.0000263357 time: 0.1186378002166748
# Iteration: 2540 loss: 0.0000263350 time: 0.10994958877563477
# Iteration: 2550 loss: 0.0000263343 time: 0.11546730995178223
# Iteration: 2560 loss: 0.0000263336 time: 0.1093909740447998
# Iteration: 2570 loss: 0.0000263330 time: 0.10960149765014648
# Iteration: 2580 loss: 0.0000263323 time: 0.11057329177856445
# Iteration: 2590 loss: 0.0000263316 time: 0.11041474342346191
# Iteration: 2600 loss: 0.0000263309 time: 0.12356972694396973
# Iteration: 2610 loss: 0.0000263303 time: 0.10817933082580566
# Iteration: 2620 loss: 0.0000263296 time: 0.11426806449890137
# Iteration: 2630 loss: 0.0000263290 time: 0.11811995506286621
# Iteration: 2640 loss: 0.0000263283 time: 0.10656404495239258
# Iteration: 2650 loss: 0.0000263277 time: 0.10361337661743164
# Iteration: 2660 loss: 0.0000263271 time: 0.11285805702209473
# Iteration: 2670 loss: 0.0000263264 time: 0.10671019554138184
# Iteration: 2680 loss: 0.0000263258 time: 0.1075894832611084
# Iteration: 2690 loss: 0.0000263252 time: 0.11063098907470703
# Iteration: 2700 loss: 0.0000263245 time: 0.11710214614868164
# Iteration: 2710 loss: 0.0000263239 time: 0.10702633857727051
# Iteration: 2720 loss: 0.0000263233 time: 0.11828947067260742
# Iteration: 2730 loss: 0.0000263227 time: 0.1166839599609375
# Iteration: 2740 loss: 0.0000263220 time: 0.10657763481140137
# Iteration: 2750 loss: 0.0000263214 time: 0.11007165908813477
# Iteration: 2760 loss: 0.0000263208 time: 0.10865354537963867
# Iteration: 2770 loss: 0.0000263201 time: 0.10163474082946777
# Iteration: 2780 loss: 0.0000263195 time: 0.10905265808105469
# Iteration: 2790 loss: 0.0000263189 time: 0.10942363739013672
# Iteration: 2800 loss: 0.0000263183 time: 0.10805678367614746
# Iteration: 2810 loss: 0.0000263176 time: 0.10424137115478516
# Iteration: 2820 loss: 0.0000263170 time: 0.11232614517211914
# Iteration: 2830 loss: 0.0000263164 time: 0.10799026489257812
# Iteration: 2840 loss: 0.0000263158 time: 0.11528730392456055
# Iteration: 2850 loss: 0.0000263151 time: 0.10560297966003418
# Iteration: 2860 loss: 0.0000263145 time: 0.11937856674194336
# Iteration: 2870 loss: 0.0000263141 time: 0.10931634902954102
# Iteration: 2880 loss: 0.0000285059 time: 0.11552643775939941
# Iteration: 2890 loss: 0.0000268642 time: 0.10835933685302734
# Iteration: 2900 loss: 0.0000315976 time: 0.10818219184875488
# Iteration: 2910 loss: 0.0000269120 time: 0.10082888603210449
# Iteration: 2920 loss: 0.0000264996 time: 0.10725092887878418
# Iteration: 2930 loss: 0.0000263824 time: 0.10262465476989746
# Iteration: 2940 loss: 0.0000263361 time: 0.12083029747009277
# Iteration: 2950 loss: 0.0000263315 time: 0.11407160758972168
# Iteration: 2960 loss: 0.0000263255 time: 0.10668516159057617
# Iteration: 2970 loss: 0.0000263211 time: 0.10945677757263184
# Iteration: 2980 loss: 0.0000263193 time: 0.11420345306396484
# Iteration: 2990 loss: 0.0000263177 time: 0.10052895545959473
# Iteration: 3000 loss: 0.0000263165 time: 0.10154080390930176

# %%
def plot_loss(history):  
    iterations = range(0, len(history) * 10, 10)  # Assuming losses are provided every 10 iterations

    plt.figure(figsize=(10, 10))

    plt.subplot(211)
    plt.plot(iterations, history, marker='*',color='green',linewidth=1)
    plt.title('Loss Function Over Iterations')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.grid()

    plt.subplot(212)
    plt.semilogy(iterations, history,linewidth=1)
    plt.title('Loss Function Over Iterations (semilog scale)')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.grid()
plot_loss(history)

# %%
plot_BC(pb.u_exact_np,model_np)

# %%
print(type(vp.points))
# Out:
# <class 'numpy.ndarray'>

# %%
color_plot(vp.NN_imposeBC)

# %%
def L2_error(xy, w):
    
    u_NN = vp.NN_imposeBC(xy)

    # Find the exact solution
    u_ex = pb.u_exact_np(xy[:,0], xy[:,1])
    u_ex = np.reshape(u_ex, (-1,1))

    integrand = (u_ex - u_NN)**2


    # Find the difference between exact and NN 
    # return (u_ex - u_NN)**2

    return np.sqrt(np.sum(w*integrand))

def semi_H1_error(xy, w):

    # Find the gradient of the exact solution
    grad_ex = np.array([pb.dudx(xy[:,0], xy[:,1]), pb.dudy(xy[:,0], xy[:,1])],dtype=np_type).T


    # Find the gradient of the NN solution
    grad_NN = vp.eval_grad_NN_BC(tf.constant(xy, dtype=tf_type))

    


    # Find the difference between exact and NN 
    pw_diff = grad_ex - grad_NN

    pw_diff = tf.reduce_sum(tf.square(pw_diff),axis=1)

    pw_diff=tf.reshape(pw_diff,(-1,1))


    return np.sqrt(np.sum(pw_diff*w))

def semi_H1_error_lambda(x,y):
    xy=np.array([[x,y]],dtype=np_type)

    # Find the gradient of the exact solution
    grad_ex = np.array([pb.dudx(xy[:,0], xy[:,1]), pb.dudy(xy[:,0], xy[:,1])],dtype=np_type).T


    # Find the gradient of the NN solution
    grad_NN = vp.eval_grad_NN_BC(tf.constant(xy, dtype=tf_type))

    


    # Find the difference between exact and NN 
    pw_diff = grad_ex - grad_NN

    pw_diff = tf.reduce_sum(tf.square(pw_diff))

    return pw_diff.numpy()

#set quad rule for calc errors
xy, w = get_quad_rule(60)

semi_H1_err = semi_H1_error(xy, w)
L2_error_ = L2_error(xy, w)
H1_err = np.sqrt(L2_error_**2 + semi_H1_err**2)

print(f"L2 error: {L2_error_}")
print(f"semi H1 error: {semi_H1_err}")
print(f"H1 error: {H1_err}")
# Out:
# L2 error: 0.0012613204402685946
# semi H1 error: 0.027958329156209678
# H1 error: 0.027986766488110118

# %%
# from scipy.integrate import dblquad
# integral,error=dblquad(lambda x,y: (pb.u_exact(x,y)-vp.u_NN_BC(x,y))*(pb.u_exact(x,y)-vp.u_NN_BC(x,y)), 0.0, 1.0,0.0,1.0)


# print('dnlquad :')
# print(np.sqrt(integral))

# %% [markdown]
# ### H1 and L2 convergence

# %%
def restart_model():
    model = tfk.models.Sequential()
    model.add(tf.keras.Input(shape=(2,),dtype=tf.float64))
    model.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(50, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tf.keras.layers.Dense(1,activation='linear',kernel_initializer=initializer,dtype=tf_type,use_bias=True))
    return model

xy, w = get_quad_rule(50)

H1 = []
L2 = []
semi = []
h = []
H = []

mesh_chain = ml.generate_regular_mesh_chain(domain, depth=12, plot=False)
index=0
di = 5

for index in [0,1,2,3,4]:
    coarse_mesh = mesh_chain[index]
    fine_mesh = mesh_chain[index+di]
    model = restart_model()
    vp=VPINN(pb,params,fine_mesh,False,coarse_mesh,model)
    history=vp.train(5000, 0.001)


    semi_H1_err = semi_H1_error(xy, w)
    L2_error_ = L2_error(xy, w)
    H1_err = np.sqrt(L2_error_**2 + semi_H1_err**2)

    H1.append(H1_err)
    semi.append(semi_H1_err)
    L2.append(L2_error_)

    h.append(fine_mesh.h_max)
    H.append(coarse_mesh.h_max)
# Out:
# -->mesh :
#      n_triangles :  64
#      n_vertices  :  41
#      n_edges     :  104
#      h_max           :  0.25
#      h_min           :  0.1767766952966369
# -->test_fun      :
#      order       :  2
#      dof         :  113
# Iteration: 0 loss: 0.0210990275 time: 47.667805194854736
# Iteration: 10 loss: 0.0204280173 time: 0.08910799026489258
# Iteration: 20 loss: 0.0203902891 time: 0.08309078216552734
# Iteration: 30 loss: 0.0203021679 time: 0.08564877510070801
# Iteration: 40 loss: 0.0202682485 time: 0.08504891395568848
# Iteration: 50 loss: 0.0202482530 time: 0.08358573913574219
# Iteration: 60 loss: 0.0202275698 time: 0.08832120895385742
# Iteration: 70 loss: 0.0202075008 time: 0.08765792846679688
# Iteration: 80 loss: 0.0201840508 time: 0.09102106094360352
# Iteration: 90 loss: 0.0201515458 time: 0.09853816032409668
# Iteration: 100 loss: 0.0201011836 time: 0.08957314491271973
# Iteration: 110 loss: 0.0200177435 time: 0.09253144264221191
# Iteration: 120 loss: 0.0198792702 time: 0.0915074348449707
# Iteration: 130 loss: 0.0196456593 time: 0.08560681343078613
# Iteration: 140 loss: 0.0192297363 time: 0.08025503158569336
# Iteration: 150 loss: 0.0187354402 time: 0.09241867065429688
# Iteration: 160 loss: 0.0186124473 time: 0.0785679817199707
# Iteration: 170 loss: 0.0184764724 time: 0.08597588539123535
# Iteration: 180 loss: 0.0182523967 time: 0.08169722557067871
# Iteration: 190 loss: 0.0178674677 time: 0.08389639854431152
# Iteration: 200 loss: 0.0172530714 time: 0.0941159725189209
# Iteration: 210 loss: 0.0165498382 time: 0.09634661674499512
# Iteration: 220 loss: 0.0158624759 time: 0.07744002342224121
# Iteration: 230 loss: 0.0151880759 time: 0.08496809005737305
# Iteration: 240 loss: 0.0147074667 time: 0.09176397323608398
# Iteration: 250 loss: 0.0143779877 time: 0.08252263069152832
# Iteration: 260 loss: 0.0141379264 time: 0.07745647430419922
# Iteration: 270 loss: 0.0139615672 time: 0.08653783798217773
# Iteration: 280 loss: 0.0138551781 time: 0.07681155204772949
# Iteration: 290 loss: 0.0138099433 time: 0.08856773376464844
# Iteration: 300 loss: 0.0137926249 time: 0.07958555221557617
# Iteration: 310 loss: 0.0137833962 time: 0.07576870918273926
# Iteration: 320 loss: 0.0137807382 time: 0.08024859428405762
# Iteration: 330 loss: 0.0137799095 time: 0.07662677764892578
# Iteration: 340 loss: 0.0137798435 time: 0.08252573013305664
# Iteration: 350 loss: 0.0137807802 time: 0.07632637023925781
# Iteration: 360 loss: 0.0137798750 time: 0.07972979545593262
# Iteration: 370 loss: 0.0137796430 time: 0.07867813110351562
# Iteration: 380 loss: 0.0137796380 time: 0.07893800735473633
# Iteration: 390 loss: 0.0137795264 time: 0.0787351131439209
# Iteration: 400 loss: 0.0137797387 time: 0.0735330581665039
# Iteration: 410 loss: 0.0137821157 time: 0.07492589950561523
# Iteration: 420 loss: 0.0137795682 time: 0.08198833465576172
# Iteration: 430 loss: 0.0137797936 time: 0.07387351989746094
# Iteration: 440 loss: 0.0137796439 time: 0.07926654815673828
# Iteration: 450 loss: 0.0137795536 time: 0.08832287788391113
# Iteration: 460 loss: 0.0137795496 time: 0.07552337646484375
# Iteration: 470 loss: 0.0137795260 time: 0.07638907432556152
# Iteration: 480 loss: 0.0137795932 time: 0.08584022521972656
# Iteration: 490 loss: 0.0137823568 time: 0.0738215446472168
# Iteration: 500 loss: 0.0137812238 time: 0.07257485389709473
# Iteration: 510 loss: 0.0137795588 time: 0.07397866249084473
# Iteration: 520 loss: 0.0137797235 time: 0.07792282104492188
# Iteration: 530 loss: 0.0137795861 time: 0.06889843940734863
# Iteration: 540 loss: 0.0137795301 time: 0.07837677001953125
# Iteration: 550 loss: 0.0137795287 time: 0.07085418701171875
# Iteration: 560 loss: 0.0137795322 time: 0.07479190826416016
# Iteration: 570 loss: 0.0137795301 time: 0.07491087913513184
# Iteration: 580 loss: 0.0137796214 time: 0.07927298545837402
# Iteration: 590 loss: 0.0137846169 time: 0.07316279411315918
# Iteration: 600 loss: 0.0137808974 time: 0.08406352996826172
# Iteration: 610 loss: 0.0137800370 time: 0.07379317283630371
# Iteration: 620 loss: 0.0137795381 time: 0.07668304443359375
# Iteration: 630 loss: 0.0137796215 time: 0.07568645477294922
# Iteration: 640 loss: 0.0137795322 time: 0.07563376426696777
# Iteration: 650 loss: 0.0137795227 time: 0.06980776786804199
# Iteration: 660 loss: 0.0137795230 time: 0.07857370376586914
# Iteration: 670 loss: 0.0137795219 time: 0.07808613777160645
# Iteration: 680 loss: 0.0137795237 time: 0.07619762420654297
# Iteration: 690 loss: 0.0137795232 time: 0.09555983543395996
# Iteration: 700 loss: 0.0137795398 time: 0.09794926643371582
# Iteration: 710 loss: 0.0137811811 time: 0.07913732528686523
# Iteration: 720 loss: 0.0137807816 time: 0.08296847343444824
# Iteration: 730 loss: 0.0137796518 time: 0.07423591613769531
# Iteration: 740 loss: 0.0137798303 time: 0.07567477226257324
# Iteration: 750 loss: 0.0137797096 time: 0.07057929039001465
# Iteration: 760 loss: 0.0137795468 time: 0.0745542049407959
# Iteration: 770 loss: 0.0137795318 time: 0.07288694381713867
# Iteration: 780 loss: 0.0137795276 time: 0.07698702812194824
# Iteration: 790 loss: 0.0137795252 time: 0.07752633094787598
# Iteration: 800 loss: 0.0137795223 time: 0.07323980331420898
# Iteration: 810 loss: 0.0137795220 time: 0.07654833793640137
# Iteration: 820 loss: 0.0137795220 time: 0.07451796531677246
# Iteration: 830 loss: 0.0137795220 time: 0.0825812816619873
# Iteration: 840 loss: 0.0137795220 time: 0.08131265640258789
# Iteration: 850 loss: 0.0137795226 time: 0.07527637481689453
# Iteration: 860 loss: 0.0137795654 time: 0.07454919815063477
# Iteration: 870 loss: 0.0137836430 time: 0.07314538955688477
# Iteration: 880 loss: 0.0137808965 time: 0.07222199440002441
# Iteration: 890 loss: 0.0137802328 time: 0.07936382293701172
# Iteration: 900 loss: 0.0137798262 time: 0.0746145248413086
# Iteration: 910 loss: 0.0137796264 time: 0.08193302154541016
# Iteration: 920 loss: 0.0137795668 time: 0.07517671585083008
# Iteration: 930 loss: 0.0137795299 time: 0.07657098770141602
# Iteration: 940 loss: 0.0137795269 time: 0.0760354995727539
# Iteration: 950 loss: 0.0137795244 time: 0.07462668418884277
# Iteration: 960 loss: 0.0137795248 time: 0.08473420143127441
# Iteration: 970 loss: 0.0137795312 time: 0.07515335083007812
# Iteration: 980 loss: 0.0137797993 time: 0.07560896873474121
# Iteration: 990 loss: 0.0137863999 time: 0.07592940330505371
# Iteration: 1000 loss: 0.0137798900 time: 0.07806777954101562
# Iteration: 1010 loss: 0.0137802175 time: 0.07401394844055176
# Iteration: 1020 loss: 0.0137795224 time: 0.07642102241516113
# Iteration: 1030 loss: 0.0137796211 time: 0.07511758804321289
# Iteration: 1040 loss: 0.0137795255 time: 0.07266378402709961
# Iteration: 1050 loss: 0.0137795269 time: 0.07319855690002441
# Iteration: 1060 loss: 0.0137795267 time: 0.07756733894348145
# Iteration: 1070 loss: 0.0137795240 time: 0.07222127914428711
# Iteration: 1080 loss: 0.0137795225 time: 0.07004237174987793
# Iteration: 1090 loss: 0.0137795219 time: 0.08389449119567871
# Iteration: 1100 loss: 0.0137795222 time: 0.07663464546203613
# Iteration: 1110 loss: 0.0137795222 time: 0.07294487953186035
# Iteration: 1120 loss: 0.0137795260 time: 0.07223367691040039
# Iteration: 1130 loss: 0.0137797438 time: 0.07449102401733398
# Iteration: 1140 loss: 0.0137888730 time: 0.0710904598236084
# Iteration: 1150 loss: 0.0137795760 time: 0.07388687133789062
# Iteration: 1160 loss: 0.0137801805 time: 0.09148406982421875
# Iteration: 1170 loss: 0.0137798659 time: 0.07372236251831055
# Iteration: 1180 loss: 0.0137795614 time: 0.06898832321166992
# Iteration: 1190 loss: 0.0137795326 time: 0.07263803482055664
# Iteration: 1200 loss: 0.0137795379 time: 0.06863188743591309
# Iteration: 1210 loss: 0.0137795224 time: 0.0839998722076416
# Iteration: 1220 loss: 0.0137795234 time: 0.07447671890258789
# Iteration: 1230 loss: 0.0137795227 time: 0.08007025718688965
# Iteration: 1240 loss: 0.0137795220 time: 0.07405281066894531
# Iteration: 1250 loss: 0.0137795219 time: 0.08256220817565918
# Iteration: 1260 loss: 0.0137795219 time: 0.07719755172729492
# Iteration: 1270 loss: 0.0137795226 time: 0.07873940467834473
# Iteration: 1280 loss: 0.0137795831 time: 0.0821084976196289
# Iteration: 1290 loss: 0.0137833850 time: 0.07338523864746094
# Iteration: 1300 loss: 0.0137795401 time: 0.06992363929748535
# Iteration: 1310 loss: 0.0137796700 time: 0.06788134574890137
# Iteration: 1320 loss: 0.0137796622 time: 0.06541800498962402
# Iteration: 1330 loss: 0.0137796089 time: 0.07682108879089355
# Iteration: 1340 loss: 0.0137802023 time: 0.08550214767456055
# Iteration: 1350 loss: 0.0137831440 time: 0.07305169105529785
# Iteration: 1360 loss: 0.0137800767 time: 0.07683920860290527
# Iteration: 1370 loss: 0.0137795300 time: 0.07516074180603027
# Iteration: 1380 loss: 0.0137796167 time: 0.0660254955291748
# Iteration: 1390 loss: 0.0137795833 time: 0.07360625267028809
# Iteration: 1400 loss: 0.0137795475 time: 0.0670628547668457
# Iteration: 1410 loss: 0.0137795305 time: 0.07240056991577148
# Iteration: 1420 loss: 0.0137795223 time: 0.07461309432983398
# Iteration: 1430 loss: 0.0137795238 time: 0.07099318504333496
# Iteration: 1440 loss: 0.0137795219 time: 0.07178258895874023
# Iteration: 1450 loss: 0.0137795221 time: 0.06812024116516113
# Iteration: 1460 loss: 0.0137795272 time: 0.07011032104492188
# Iteration: 1470 loss: 0.0137798679 time: 0.07123899459838867
# Iteration: 1480 loss: 0.0137887196 time: 0.07414126396179199
# Iteration: 1490 loss: 0.0137796912 time: 0.07108855247497559
# Iteration: 1500 loss: 0.0137797957 time: 0.0707244873046875
# Iteration: 1510 loss: 0.0137798309 time: 0.07090449333190918
# Iteration: 1520 loss: 0.0137796207 time: 0.07519865036010742
# Iteration: 1530 loss: 0.0137795227 time: 0.0728151798248291
# Iteration: 1540 loss: 0.0137795350 time: 0.07490396499633789
# Iteration: 1550 loss: 0.0137795238 time: 0.07363700866699219
# Iteration: 1560 loss: 0.0137795237 time: 0.07560157775878906
# Iteration: 1570 loss: 0.0137795219 time: 0.07814311981201172
# Iteration: 1580 loss: 0.0137795221 time: 0.07027244567871094
# Iteration: 1590 loss: 0.0137795220 time: 0.06873226165771484
# Iteration: 1600 loss: 0.0137795219 time: 0.07077240943908691
# Iteration: 1610 loss: 0.0137795219 time: 0.07250070571899414
# Iteration: 1620 loss: 0.0137795221 time: 0.08315539360046387
# Iteration: 1630 loss: 0.0137795392 time: 0.08932352066040039
# Iteration: 1640 loss: 0.0137818907 time: 0.07988643646240234
# Iteration: 1650 loss: 0.0137814450 time: 0.07753944396972656
# Iteration: 1660 loss: 0.0137800228 time: 0.06658244132995605
# Iteration: 1670 loss: 0.0137795965 time: 0.07484984397888184
# Iteration: 1680 loss: 0.0137795269 time: 0.06853723526000977
# Iteration: 1690 loss: 0.0137795416 time: 0.07107710838317871
# Iteration: 1700 loss: 0.0137796763 time: 0.07150864601135254
# Iteration: 1710 loss: 0.0137831572 time: 0.06883549690246582
# Iteration: 1720 loss: 0.0137803746 time: 0.07363128662109375
# Iteration: 1730 loss: 0.0137803552 time: 0.07136297225952148
# Iteration: 1740 loss: 0.0137796562 time: 0.06761932373046875
# Iteration: 1750 loss: 0.0137795224 time: 0.07561802864074707
# Iteration: 1760 loss: 0.0137795354 time: 0.0727529525756836
# Iteration: 1770 loss: 0.0137795307 time: 0.07634258270263672
# Iteration: 1780 loss: 0.0137795245 time: 0.07926726341247559
# Iteration: 1790 loss: 0.0137795219 time: 0.06841373443603516
# Iteration: 1800 loss: 0.0137795227 time: 0.07057595252990723
# Iteration: 1810 loss: 0.0137795221 time: 0.08104538917541504
# Iteration: 1820 loss: 0.0137795226 time: 0.06614947319030762
# Iteration: 1830 loss: 0.0137795262 time: 0.07062935829162598
# Iteration: 1840 loss: 0.0137796265 time: 0.07591938972473145
# Iteration: 1850 loss: 0.0137843222 time: 0.07509732246398926
# Iteration: 1860 loss: 0.0137819743 time: 0.0685415267944336
# Iteration: 1870 loss: 0.0137798937 time: 0.07832622528076172
# Iteration: 1880 loss: 0.0137798319 time: 0.0692298412322998
# Iteration: 1890 loss: 0.0137795498 time: 0.07917189598083496
# Iteration: 1900 loss: 0.0137795595 time: 0.06997084617614746
# Iteration: 1910 loss: 0.0137795353 time: 0.06714272499084473
# Iteration: 1920 loss: 0.0137795220 time: 0.07160425186157227
# Iteration: 1930 loss: 0.0137795228 time: 0.07486486434936523
# Iteration: 1940 loss: 0.0137795226 time: 0.06801748275756836
# Iteration: 1950 loss: 0.0137795221 time: 0.07155346870422363
# Iteration: 1960 loss: 0.0137795219 time: 0.07103300094604492
# Iteration: 1970 loss: 0.0137795219 time: 0.07246160507202148
# Iteration: 1980 loss: 0.0137795219 time: 0.06669139862060547
# Iteration: 1990 loss: 0.0137795235 time: 0.07299399375915527
# Iteration: 2000 loss: 0.0137797074 time: 0.07117009162902832
# Iteration: 2010 loss: 0.0137827090 time: 0.0724189281463623
# Iteration: 2020 loss: 0.0137805234 time: 0.07904267311096191
# Iteration: 2030 loss: 0.0137796124 time: 0.06862401962280273
# Iteration: 2040 loss: 0.0137795392 time: 0.07946562767028809
# Iteration: 2050 loss: 0.0137796331 time: 0.07568550109863281
# Iteration: 2060 loss: 0.0137808485 time: 0.07093143463134766
# Iteration: 2070 loss: 0.0137807078 time: 0.07335495948791504
# Iteration: 2080 loss: 0.0137798756 time: 0.07847929000854492
# Iteration: 2090 loss: 0.0137796029 time: 0.06374192237854004
# Iteration: 2100 loss: 0.0137795519 time: 0.06979751586914062
# Iteration: 2110 loss: 0.0137795467 time: 0.07422351837158203
# Iteration: 2120 loss: 0.0137795410 time: 0.06970834732055664
# Iteration: 2130 loss: 0.0137795239 time: 0.07498908042907715
# Iteration: 2140 loss: 0.0137795265 time: 0.07523012161254883
# Iteration: 2150 loss: 0.0137795239 time: 0.06525540351867676
# Iteration: 2160 loss: 0.0137795293 time: 0.06483340263366699
# Iteration: 2170 loss: 0.0137796843 time: 0.0717768669128418
# Iteration: 2180 loss: 0.0137850877 time: 0.06899023056030273
# Iteration: 2190 loss: 0.0137819954 time: 0.07137012481689453
# Iteration: 2200 loss: 0.0137798234 time: 0.07996273040771484
# Iteration: 2210 loss: 0.0137797050 time: 0.06982803344726562
# Iteration: 2220 loss: 0.0137796066 time: 0.0621187686920166
# Iteration: 2230 loss: 0.0137795254 time: 0.08069777488708496
# Iteration: 2240 loss: 0.0137795325 time: 0.06965255737304688
# Iteration: 2250 loss: 0.0137795274 time: 0.07460904121398926
# Iteration: 2260 loss: 0.0137795240 time: 0.06717753410339355
# Iteration: 2270 loss: 0.0137795227 time: 0.06528019905090332
# Iteration: 2280 loss: 0.0137795222 time: 0.06804060935974121
# Iteration: 2290 loss: 0.0137795219 time: 0.07311487197875977
# Iteration: 2300 loss: 0.0137795219 time: 0.0694129467010498
# Iteration: 2310 loss: 0.0137795219 time: 0.07106232643127441
# Iteration: 2320 loss: 0.0137795219 time: 0.06848645210266113
# Iteration: 2330 loss: 0.0137795220 time: 0.07511591911315918
# Iteration: 2340 loss: 0.0137795282 time: 0.07235836982727051
# Iteration: 2350 loss: 0.0137800708 time: 0.09097814559936523
# Iteration: 2360 loss: 0.0137861871 time: 0.07293844223022461
# Iteration: 2370 loss: 0.0137820811 time: 0.06444263458251953
# Iteration: 2380 loss: 0.0137803304 time: 0.0724954605102539
# Iteration: 2390 loss: 0.0137798589 time: 0.07074809074401855
# Iteration: 2400 loss: 0.0137796303 time: 0.07447242736816406
# Iteration: 2410 loss: 0.0137795588 time: 0.0705418586730957
# Iteration: 2420 loss: 0.0137795363 time: 0.07522106170654297
# Iteration: 2430 loss: 0.0137795272 time: 0.06983375549316406
# Iteration: 2440 loss: 0.0137795233 time: 0.06682133674621582
# Iteration: 2450 loss: 0.0137795220 time: 0.0727837085723877
# Iteration: 2460 loss: 0.0137795219 time: 0.07035207748413086
# Iteration: 2470 loss: 0.0137795220 time: 0.07449483871459961
# Iteration: 2480 loss: 0.0137795219 time: 0.08042335510253906
# Iteration: 2490 loss: 0.0137795219 time: 0.07373213768005371
# Iteration: 2500 loss: 0.0137795219 time: 0.06922793388366699
# Iteration: 2510 loss: 0.0137795234 time: 0.07037878036499023
# Iteration: 2520 loss: 0.0137796497 time: 0.07553577423095703
# Iteration: 2530 loss: 0.0137896187 time: 0.07024455070495605
# Iteration: 2540 loss: 0.0137809856 time: 0.07689857482910156
# Iteration: 2550 loss: 0.0137803616 time: 0.06504321098327637
# Iteration: 2560 loss: 0.0137796718 time: 0.07416677474975586
# Iteration: 2570 loss: 0.0137796144 time: 0.0681765079498291
# Iteration: 2580 loss: 0.0137795773 time: 0.06698179244995117
# Iteration: 2590 loss: 0.0137795274 time: 0.06895303726196289
# Iteration: 2600 loss: 0.0137795258 time: 0.07268786430358887
# Iteration: 2610 loss: 0.0137795226 time: 0.06569647789001465
# Iteration: 2620 loss: 0.0137795227 time: 0.06720471382141113
# Iteration: 2630 loss: 0.0137795220 time: 0.0740354061126709
# Iteration: 2640 loss: 0.0137795219 time: 0.06989336013793945
# Iteration: 2650 loss: 0.0137795219 time: 0.06764101982116699
# Iteration: 2660 loss: 0.0137795219 time: 0.07111501693725586
# Iteration: 2670 loss: 0.0137795219 time: 0.06793045997619629
# Iteration: 2680 loss: 0.0137795219 time: 0.06862711906433105
# Iteration: 2690 loss: 0.0137795219 time: 0.07247066497802734
# Iteration: 2700 loss: 0.0137795219 time: 0.07179713249206543
# Iteration: 2710 loss: 0.0137795219 time: 0.0785071849822998
# Iteration: 2720 loss: 0.0137795219 time: 0.07368111610412598
# Iteration: 2730 loss: 0.0137795219 time: 0.0669548511505127
# Iteration: 2740 loss: 0.0137795222 time: 0.07872962951660156
# Iteration: 2750 loss: 0.0137795653 time: 0.07049918174743652
# Iteration: 2760 loss: 0.0137867915 time: 0.07185530662536621
# Iteration: 2770 loss: 0.0137834942 time: 0.07213711738586426
# Iteration: 2780 loss: 0.0137806064 time: 0.07713675498962402
# Iteration: 2790 loss: 0.0137796644 time: 0.0692298412322998
# Iteration: 2800 loss: 0.0137795377 time: 0.06898093223571777
# Iteration: 2810 loss: 0.0137795709 time: 0.07905721664428711
# Iteration: 2820 loss: 0.0137795457 time: 0.06778693199157715
# Iteration: 2830 loss: 0.0137795324 time: 0.07623553276062012
# Iteration: 2840 loss: 0.0137795253 time: 0.07344198226928711
# Iteration: 2850 loss: 0.0137795230 time: 0.06968069076538086
# Iteration: 2860 loss: 0.0137795223 time: 0.06830453872680664
# Iteration: 2870 loss: 0.0137795220 time: 0.07257246971130371
# Iteration: 2880 loss: 0.0137795219 time: 0.07699823379516602
# Iteration: 2890 loss: 0.0137795219 time: 0.07151269912719727
# Iteration: 2900 loss: 0.0137795219 time: 0.08140325546264648
# Iteration: 2910 loss: 0.0137795219 time: 0.08277201652526855
# Iteration: 2920 loss: 0.0137795219 time: 0.07609891891479492
# Iteration: 2930 loss: 0.0137795219 time: 0.07899332046508789
# Iteration: 2940 loss: 0.0137795219 time: 0.06986165046691895
# Iteration: 2950 loss: 0.0137795220 time: 0.07200193405151367
# Iteration: 2960 loss: 0.0137795340 time: 0.0760040283203125
# Iteration: 2970 loss: 0.0137813015 time: 0.07176041603088379
# Iteration: 2980 loss: 0.0137803854 time: 0.07306408882141113
# Iteration: 2990 loss: 0.0137804400 time: 0.08068346977233887
# Iteration: 3000 loss: 0.0137798219 time: 0.06803059577941895
# Iteration: 3010 loss: 0.0137795322 time: 0.08060836791992188
# Iteration: 3020 loss: 0.0137795388 time: 0.07175397872924805
# Iteration: 3030 loss: 0.0137795374 time: 0.06743144989013672
# Iteration: 3040 loss: 0.0137795242 time: 0.07307696342468262
# Iteration: 3050 loss: 0.0137795259 time: 0.07500219345092773
# Iteration: 3060 loss: 0.0137795226 time: 0.07805013656616211
# Iteration: 3070 loss: 0.0137795221 time: 0.06967926025390625
# Iteration: 3080 loss: 0.0137795220 time: 0.06955814361572266
# Iteration: 3090 loss: 0.0137795219 time: 0.06735444068908691
# Iteration: 3100 loss: 0.0137795219 time: 0.0711369514465332
# Iteration: 3110 loss: 0.0137795219 time: 0.06897139549255371
# Iteration: 3120 loss: 0.0137795219 time: 0.07574725151062012
# Iteration: 3130 loss: 0.0137795219 time: 0.0696859359741211
# Iteration: 3140 loss: 0.0137795219 time: 0.07759523391723633
# Iteration: 3150 loss: 0.0137795219 time: 0.07889747619628906
# Iteration: 3160 loss: 0.0137795219 time: 0.07223343849182129
# Iteration: 3170 loss: 0.0137795219 time: 0.07075977325439453
# Iteration: 3180 loss: 0.0137795219 time: 0.06635189056396484
# Iteration: 3190 loss: 0.0137795219 time: 0.0659642219543457
# Iteration: 3200 loss: 0.0137795248 time: 0.07263493537902832
# Iteration: 3210 loss: 0.0137801044 time: 0.07037997245788574
# Iteration: 3220 loss: 0.0137844374 time: 0.06483721733093262
# Iteration: 3230 loss: 0.0137817063 time: 0.07213187217712402
# Iteration: 3240 loss: 0.0137797880 time: 0.06763887405395508
# Iteration: 3250 loss: 0.0137795632 time: 0.07021808624267578
# Iteration: 3260 loss: 0.0137796007 time: 0.07477068901062012
# Iteration: 3270 loss: 0.0137795698 time: 0.0674135684967041
# Iteration: 3280 loss: 0.0137795399 time: 0.06970000267028809
# Iteration: 3290 loss: 0.0137795268 time: 0.07003045082092285
# Iteration: 3300 loss: 0.0137795235 time: 0.07201528549194336
# Iteration: 3310 loss: 0.0137795225 time: 0.06991147994995117
# Iteration: 3320 loss: 0.0137795221 time: 0.07088804244995117
# Iteration: 3330 loss: 0.0137795220 time: 0.06448864936828613
# Iteration: 3340 loss: 0.0137795219 time: 0.06372547149658203
# Iteration: 3350 loss: 0.0137795219 time: 0.07719182968139648
# Iteration: 3360 loss: 0.0137795219 time: 0.0661318302154541
# Iteration: 3370 loss: 0.0137795219 time: 0.06455111503601074
# Iteration: 3380 loss: 0.0137795219 time: 0.06478571891784668
# Iteration: 3390 loss: 0.0137795219 time: 0.07694220542907715
# Iteration: 3400 loss: 0.0137795219 time: 0.06377458572387695
# Iteration: 3410 loss: 0.0137795219 time: 0.07100796699523926
# Iteration: 3420 loss: 0.0137795219 time: 0.06415843963623047
# Iteration: 3430 loss: 0.0137795220 time: 0.07311272621154785
# Iteration: 3440 loss: 0.0137795319 time: 0.07445597648620605
# Iteration: 3450 loss: 0.0137813672 time: 0.06768417358398438
# Iteration: 3460 loss: 0.0137813716 time: 0.07079863548278809
# Iteration: 3470 loss: 0.0137805905 time: 0.07075738906860352
# Iteration: 3480 loss: 0.0137798521 time: 0.0691537857055664
# Iteration: 3490 loss: 0.0137796444 time: 0.06745529174804688
# Iteration: 3500 loss: 0.0137795991 time: 0.07142424583435059
# Iteration: 3510 loss: 0.0137795402 time: 0.07329869270324707
# Iteration: 3520 loss: 0.0137795319 time: 0.06606888771057129
# Iteration: 3530 loss: 0.0137795237 time: 0.06921577453613281
# Iteration: 3540 loss: 0.0137795224 time: 0.0709233283996582
# Iteration: 3550 loss: 0.0137795221 time: 0.06867480278015137
# Iteration: 3560 loss: 0.0137795220 time: 0.07497334480285645
# Iteration: 3570 loss: 0.0137795219 time: 0.06893706321716309
# Iteration: 3580 loss: 0.0137795219 time: 0.07347321510314941
# Iteration: 3590 loss: 0.0137795219 time: 0.0769965648651123
# Iteration: 3600 loss: 0.0137795219 time: 0.066741943359375
# Iteration: 3610 loss: 0.0137795219 time: 0.07156896591186523
# Iteration: 3620 loss: 0.0137795219 time: 0.07082176208496094
# Iteration: 3630 loss: 0.0137795219 time: 0.06777572631835938
# Iteration: 3640 loss: 0.0137795219 time: 0.06670975685119629
# Iteration: 3650 loss: 0.0137795219 time: 0.07336282730102539
# Iteration: 3660 loss: 0.0137795256 time: 0.0654599666595459
# Iteration: 3670 loss: 0.0137799535 time: 0.061333417892456055
# Iteration: 3680 loss: 0.0137882738 time: 0.06750798225402832
# Iteration: 3690 loss: 0.0137815069 time: 0.06649994850158691
# Iteration: 3700 loss: 0.0137799483 time: 0.0678715705871582
# Iteration: 3710 loss: 0.0137796178 time: 0.07578372955322266
# Iteration: 3720 loss: 0.0137795304 time: 0.08172774314880371
# Iteration: 3730 loss: 0.0137795252 time: 0.06573224067687988
# Iteration: 3740 loss: 0.0137795270 time: 0.0728459358215332
# Iteration: 3750 loss: 0.0137795276 time: 0.07067370414733887
# Iteration: 3760 loss: 0.0137795235 time: 0.07449579238891602
# Iteration: 3770 loss: 0.0137795219 time: 0.07518434524536133
# Iteration: 3780 loss: 0.0137795221 time: 0.07350659370422363
# Iteration: 3790 loss: 0.0137795219 time: 0.07280993461608887
# Iteration: 3800 loss: 0.0137795219 time: 0.06333541870117188
# Iteration: 3810 loss: 0.0137795219 time: 0.07203960418701172
# Iteration: 3820 loss: 0.0137795219 time: 0.06586456298828125
# Iteration: 3830 loss: 0.0137795219 time: 0.0637049674987793
# Iteration: 3840 loss: 0.0137795219 time: 0.07027292251586914
# Iteration: 3850 loss: 0.0137795219 time: 0.06750226020812988
# Iteration: 3860 loss: 0.0137795219 time: 0.0681145191192627
# Iteration: 3870 loss: 0.0137795219 time: 0.0856637954711914
# Iteration: 3880 loss: 0.0137795219 time: 0.06529116630554199
# Iteration: 3890 loss: 0.0137795223 time: 0.06814765930175781
# Iteration: 3900 loss: 0.0137795729 time: 0.06535983085632324
# Iteration: 3910 loss: 0.0137860206 time: 0.06776952743530273
# Iteration: 3920 loss: 0.0137797684 time: 0.06882977485656738
# Iteration: 3930 loss: 0.0137796959 time: 0.07102131843566895
# Iteration: 3940 loss: 0.0137795676 time: 0.06844425201416016
# Iteration: 3950 loss: 0.0137795324 time: 0.06816315650939941
# Iteration: 3960 loss: 0.0137795236 time: 0.0697164535522461
# Iteration: 3970 loss: 0.0137795229 time: 0.06395149230957031
# Iteration: 3980 loss: 0.0137795241 time: 0.06460213661193848
# Iteration: 3990 loss: 0.0137795229 time: 0.06965065002441406
# Iteration: 4000 loss: 0.0137795228 time: 0.06946516036987305
# Iteration: 4010 loss: 0.0137795234 time: 0.07192397117614746
# Iteration: 4020 loss: 0.0137795409 time: 0.0718851089477539
# Iteration: 4030 loss: 0.0137802213 time: 0.07405209541320801
# Iteration: 4040 loss: 0.0137839101 time: 0.06832408905029297
# Iteration: 4050 loss: 0.0137795357 time: 0.07199549674987793
# Iteration: 4060 loss: 0.0137800902 time: 0.06554889678955078
# Iteration: 4070 loss: 0.0137795323 time: 0.0727987289428711
# Iteration: 4080 loss: 0.0137795864 time: 0.06796884536743164
# Iteration: 4090 loss: 0.0137795347 time: 0.06907105445861816
# Iteration: 4100 loss: 0.0137795225 time: 0.06901240348815918
# Iteration: 4110 loss: 0.0137795246 time: 0.06314539909362793
# Iteration: 4120 loss: 0.0137795233 time: 0.06615662574768066
# Iteration: 4130 loss: 0.0137795224 time: 0.07066035270690918
# Iteration: 4140 loss: 0.0137795221 time: 0.06971287727355957
# Iteration: 4150 loss: 0.0137795219 time: 0.06934809684753418
# Iteration: 4160 loss: 0.0137795219 time: 0.0717167854309082
# Iteration: 4170 loss: 0.0137795219 time: 0.07426905632019043
# Iteration: 4180 loss: 0.0137795219 time: 0.07384896278381348
# Iteration: 4190 loss: 0.0137795219 time: 0.06673765182495117
# Iteration: 4200 loss: 0.0137795219 time: 0.07785892486572266
# Iteration: 4210 loss: 0.0137795229 time: 0.07258725166320801
# Iteration: 4220 loss: 0.0137795773 time: 0.0754859447479248
# Iteration: 4230 loss: 0.0137843176 time: 0.06655144691467285
# Iteration: 4240 loss: 0.0137833434 time: 0.0665292739868164
# Iteration: 4250 loss: 0.0137795910 time: 0.06246471405029297
# Iteration: 4260 loss: 0.0137796260 time: 0.06137895584106445
# Iteration: 4270 loss: 0.0137796692 time: 0.0715799331665039
# Iteration: 4280 loss: 0.0137795786 time: 0.06110239028930664
# Iteration: 4290 loss: 0.0137795238 time: 0.06571197509765625
# Iteration: 4300 loss: 0.0137795265 time: 0.07418680191040039
# Iteration: 4310 loss: 0.0137795241 time: 0.07026553153991699
# Iteration: 4320 loss: 0.0137795221 time: 0.06958484649658203
# Iteration: 4330 loss: 0.0137795221 time: 0.06418132781982422
# Iteration: 4340 loss: 0.0137795220 time: 0.0714421272277832
# Iteration: 4350 loss: 0.0137795219 time: 0.08814811706542969
# Iteration: 4360 loss: 0.0137795219 time: 0.0631415843963623
# Iteration: 4370 loss: 0.0137795219 time: 0.06456565856933594
# Iteration: 4380 loss: 0.0137795219 time: 0.06819725036621094
# Iteration: 4390 loss: 0.0137795233 time: 0.06656408309936523
# Iteration: 4400 loss: 0.0137796847 time: 0.06636786460876465
# Iteration: 4410 loss: 0.0137841790 time: 0.07282662391662598
# Iteration: 4420 loss: 0.0137800871 time: 0.0638580322265625
# Iteration: 4430 loss: 0.0137795435 time: 0.06467318534851074
# Iteration: 4440 loss: 0.0137795416 time: 0.07398843765258789
# Iteration: 4450 loss: 0.0137795529 time: 0.06633615493774414
# Iteration: 4460 loss: 0.0137795441 time: 0.06800222396850586
# Iteration: 4470 loss: 0.0137795284 time: 0.07467389106750488
# Iteration: 4480 loss: 0.0137795222 time: 0.06624865531921387
# Iteration: 4490 loss: 0.0137795225 time: 0.06401610374450684
# Iteration: 4500 loss: 0.0137795222 time: 0.0723421573638916
# Iteration: 4510 loss: 0.0137795221 time: 0.06766963005065918
# Iteration: 4520 loss: 0.0137795276 time: 0.07681441307067871
# Iteration: 4530 loss: 0.0137798904 time: 0.07029390335083008
# Iteration: 4540 loss: 0.0137879407 time: 0.06865143775939941
# Iteration: 4550 loss: 0.0137795452 time: 0.0713965892791748
# Iteration: 4560 loss: 0.0137800372 time: 0.06776595115661621
# Iteration: 4570 loss: 0.0137797919 time: 0.06865143775939941
# Iteration: 4580 loss: 0.0137795595 time: 0.06984496116638184
# Iteration: 4590 loss: 0.0137795341 time: 0.07142281532287598
# Iteration: 4600 loss: 0.0137795308 time: 0.06492853164672852
# Iteration: 4610 loss: 0.0137795246 time: 0.07277321815490723
# Iteration: 4620 loss: 0.0137795225 time: 0.06664681434631348
# Iteration: 4630 loss: 0.0137795222 time: 0.06558918952941895
# Iteration: 4640 loss: 0.0137795221 time: 0.07561159133911133
# Iteration: 4650 loss: 0.0137795219 time: 0.06716513633728027
# Iteration: 4660 loss: 0.0137795219 time: 0.06975007057189941
# Iteration: 4670 loss: 0.0137795219 time: 0.06505513191223145
# Iteration: 4680 loss: 0.0137795219 time: 0.07007861137390137
# Iteration: 4690 loss: 0.0137795219 time: 0.06836271286010742
# Iteration: 4700 loss: 0.0137795219 time: 0.0613703727722168
# Iteration: 4710 loss: 0.0137795219 time: 0.06963729858398438
# Iteration: 4720 loss: 0.0137795219 time: 0.07278203964233398
# Iteration: 4730 loss: 0.0137795219 time: 0.06509780883789062
# Iteration: 4740 loss: 0.0137795219 time: 0.07188630104064941
# Iteration: 4750 loss: 0.0137795219 time: 0.06810331344604492
# Iteration: 4760 loss: 0.0137795254 time: 0.06733059883117676
# Iteration: 4770 loss: 0.0137800662 time: 0.07798242568969727
# Iteration: 4780 loss: 0.0137818742 time: 0.06759381294250488
# Iteration: 4790 loss: 0.0137803285 time: 0.07166934013366699
# Iteration: 4800 loss: 0.0137796778 time: 0.0682229995727539
# Iteration: 4810 loss: 0.0137796095 time: 0.06743669509887695
# Iteration: 4820 loss: 0.0137795927 time: 0.07040286064147949
# Iteration: 4830 loss: 0.0137795547 time: 0.07168316841125488
# Iteration: 4840 loss: 0.0137795321 time: 0.07760429382324219
# Iteration: 4850 loss: 0.0137795259 time: 0.06653761863708496
# Iteration: 4860 loss: 0.0137795236 time: 0.0631096363067627
# Iteration: 4870 loss: 0.0137795229 time: 0.07618045806884766
# Iteration: 4880 loss: 0.0137795229 time: 0.07062435150146484
# Iteration: 4890 loss: 0.0137795296 time: 0.07145881652832031
# Iteration: 4900 loss: 0.0137797427 time: 0.07580184936523438
# Iteration: 4910 loss: 0.0137852938 time: 0.07030510902404785
# Iteration: 4920 loss: 0.0137814749 time: 0.07056140899658203
# Iteration: 4930 loss: 0.0137795223 time: 0.07496023178100586
# Iteration: 4940 loss: 0.0137797635 time: 0.06695103645324707
# Iteration: 4950 loss: 0.0137795258 time: 0.06899833679199219
# Iteration: 4960 loss: 0.0137795455 time: 0.06528639793395996
# Iteration: 4970 loss: 0.0137795309 time: 0.06815361976623535
# Iteration: 4980 loss: 0.0137795221 time: 0.06408238410949707
# Iteration: 4990 loss: 0.0137795220 time: 0.06796765327453613
# Iteration: 5000 loss: 0.0137795221 time: 0.06511735916137695
# -->mesh :
#      n_triangles :  128
#      n_vertices  :  81
#      n_edges     :  208
#      h_max           :  0.1767766952966369
#      h_min           :  0.125
# -->test_fun      :
#      order       :  2
#      dof         :  225
# Iteration: 0 loss: 0.0006796793 time: 54.4149010181427
# Iteration: 10 loss: 0.0006545162 time: 0.12110066413879395
# Iteration: 20 loss: 0.0006447922 time: 0.1141061782836914
# Iteration: 30 loss: 0.0006419746 time: 0.11327886581420898
# Iteration: 40 loss: 0.0006411467 time: 0.12497854232788086
# Iteration: 50 loss: 0.0006403608 time: 0.12241888046264648
# Iteration: 60 loss: 0.0006398871 time: 0.12101960182189941
# Iteration: 70 loss: 0.0006396269 time: 0.11372160911560059
# Iteration: 80 loss: 0.0006393917 time: 0.12640953063964844
# Iteration: 90 loss: 0.0006391718 time: 0.1196279525756836
# Iteration: 100 loss: 0.0006389494 time: 0.12353062629699707
# Iteration: 110 loss: 0.0006387202 time: 0.10593867301940918
# Iteration: 120 loss: 0.0006384793 time: 0.1001429557800293
# Iteration: 130 loss: 0.0006382179 time: 0.10675406455993652
# Iteration: 140 loss: 0.0006379256 time: 0.10810089111328125
# Iteration: 150 loss: 0.0006375885 time: 0.10312104225158691
# Iteration: 160 loss: 0.0006371881 time: 0.10074877738952637
# Iteration: 170 loss: 0.0006366990 time: 0.10560894012451172
# Iteration: 180 loss: 0.0006360866 time: 0.10848736763000488
# Iteration: 190 loss: 0.0006353038 time: 0.10036849975585938
# Iteration: 200 loss: 0.0006342899 time: 0.10692334175109863
# Iteration: 210 loss: 0.0006329754 time: 0.10184288024902344
# Iteration: 220 loss: 0.0006313023 time: 0.10545659065246582
# Iteration: 230 loss: 0.0006292719 time: 0.10502958297729492
# Iteration: 240 loss: 0.0006270070 time: 0.10869455337524414
# Iteration: 250 loss: 0.0006247258 time: 0.0951240062713623
# Iteration: 260 loss: 0.0006224939 time: 0.09488558769226074
# Iteration: 270 loss: 0.0006200582 time: 0.11225581169128418
# Iteration: 280 loss: 0.0006172580 time: 0.12098336219787598
# Iteration: 290 loss: 0.0006140910 time: 0.12021255493164062
# Iteration: 300 loss: 0.0006106227 time: 0.09517145156860352
# Iteration: 310 loss: 0.0006070973 time: 0.10073685646057129
# Iteration: 320 loss: 0.0006037279 time: 0.09746360778808594
# Iteration: 330 loss: 0.0006004411 time: 0.09749507904052734
# Iteration: 340 loss: 0.0005969559 time: 0.09507894515991211
# Iteration: 350 loss: 0.0005932364 time: 0.09917402267456055
# Iteration: 360 loss: 0.0005878488 time: 0.09851646423339844
# Iteration: 370 loss: 0.0005751361 time: 0.08828163146972656
# Iteration: 380 loss: 0.0005396795 time: 0.10002636909484863
# Iteration: 390 loss: 0.0004903839 time: 0.09940981864929199
# Iteration: 400 loss: 0.0004554420 time: 0.09668326377868652
# Iteration: 410 loss: 0.0004223063 time: 0.0957803726196289
# Iteration: 420 loss: 0.0003894999 time: 0.09616851806640625
# Iteration: 430 loss: 0.0003577114 time: 0.0963594913482666
# Iteration: 440 loss: 0.0003258387 time: 0.10289311408996582
# Iteration: 450 loss: 0.0003017383 time: 0.10374808311462402
# Iteration: 460 loss: 0.0002869652 time: 0.09530019760131836
# Iteration: 470 loss: 0.0002772841 time: 0.09647417068481445
# Iteration: 480 loss: 0.0002701996 time: 0.09734439849853516
# Iteration: 490 loss: 0.0002646273 time: 0.09790802001953125
# Iteration: 500 loss: 0.0002595987 time: 0.10778331756591797
# Iteration: 510 loss: 0.0002545533 time: 0.0938711166381836
# Iteration: 520 loss: 0.0002493951 time: 0.09469914436340332
# Iteration: 530 loss: 0.0002435913 time: 0.09856343269348145
# Iteration: 540 loss: 0.0002364106 time: 0.09955954551696777
# Iteration: 550 loss: 0.0002287305 time: 0.10383248329162598
# Iteration: 560 loss: 0.0002219479 time: 0.09590721130371094
# Iteration: 570 loss: 0.0002165002 time: 0.10111522674560547
# Iteration: 580 loss: 0.0002134686 time: 0.10019659996032715
# Iteration: 590 loss: 0.0002125557 time: 0.09282946586608887
# Iteration: 600 loss: 0.0002117669 time: 0.09685254096984863
# Iteration: 610 loss: 0.0002111593 time: 0.09931325912475586
# Iteration: 620 loss: 0.0002108003 time: 0.09436869621276855
# Iteration: 630 loss: 0.0002106366 time: 0.09717822074890137
# Iteration: 640 loss: 0.0002110488 time: 0.0946497917175293
# Iteration: 650 loss: 0.0002105464 time: 0.10652637481689453
# Iteration: 660 loss: 0.0002103153 time: 0.10305023193359375
# Iteration: 670 loss: 0.0002100805 time: 0.0994410514831543
# Iteration: 680 loss: 0.0002103597 time: 0.10507321357727051
# Iteration: 690 loss: 0.0002099348 time: 0.11099505424499512
# Iteration: 700 loss: 0.0002100865 time: 0.10140275955200195
# Iteration: 710 loss: 0.0002098752 time: 0.129655122756958
# Iteration: 720 loss: 0.0002097573 time: 0.1294269561767578
# Iteration: 730 loss: 0.0002097008 time: 0.1265397071838379
# Iteration: 740 loss: 0.0002096540 time: 0.13780856132507324
# Iteration: 750 loss: 0.0002106216 time: 0.12856650352478027
# Iteration: 760 loss: 0.0002100751 time: 0.10815596580505371
# Iteration: 770 loss: 0.0002094528 time: 0.10806131362915039
# Iteration: 780 loss: 0.0002094171 time: 0.10539555549621582
# Iteration: 790 loss: 0.0002093447 time: 0.11142110824584961
# Iteration: 800 loss: 0.0002092559 time: 0.09461736679077148
# Iteration: 810 loss: 0.0002091842 time: 0.11104440689086914
# Iteration: 820 loss: 0.0002091817 time: 0.12256360054016113
# Iteration: 830 loss: 0.0002109111 time: 0.11475610733032227
# Iteration: 840 loss: 0.0002091628 time: 0.15018177032470703
# Iteration: 850 loss: 0.0002088845 time: 0.13777804374694824
# Iteration: 860 loss: 0.0002088627 time: 0.13598299026489258
# Iteration: 870 loss: 0.0002087251 time: 0.13109159469604492
# Iteration: 880 loss: 0.0002086255 time: 0.12425422668457031
# Iteration: 890 loss: 0.0002085141 time: 0.12195920944213867
# Iteration: 900 loss: 0.0002084047 time: 0.11939740180969238
# Iteration: 910 loss: 0.0002082849 time: 0.1003713607788086
# Iteration: 920 loss: 0.0002082055 time: 0.10785102844238281
# Iteration: 930 loss: 0.0002115126 time: 0.1001594066619873
# Iteration: 940 loss: 0.0002089515 time: 0.12347793579101562
# Iteration: 950 loss: 0.0002081307 time: 0.09595561027526855
# Iteration: 960 loss: 0.0002077197 time: 0.09027910232543945
# Iteration: 970 loss: 0.0002075241 time: 0.09633255004882812
# Iteration: 980 loss: 0.0002073712 time: 0.0975654125213623
# Iteration: 990 loss: 0.0002072171 time: 0.10832691192626953
# Iteration: 1000 loss: 0.0002070554 time: 0.10103225708007812
# Iteration: 1010 loss: 0.0002069006 time: 0.10935235023498535
# Iteration: 1020 loss: 0.0002067449 time: 0.11522364616394043
# Iteration: 1030 loss: 0.0002065924 time: 0.12070178985595703
# Iteration: 1040 loss: 0.0002064450 time: 0.10938620567321777
# Iteration: 1050 loss: 0.0002063102 time: 0.09922218322753906
# Iteration: 1060 loss: 0.0002077483 time: 0.10209965705871582
# Iteration: 1070 loss: 0.0002073713 time: 0.1024010181427002
# Iteration: 1080 loss: 0.0002060280 time: 0.10672330856323242
# Iteration: 1090 loss: 0.0002059930 time: 0.09817838668823242
# Iteration: 1100 loss: 0.0002058982 time: 0.1029813289642334
# Iteration: 1110 loss: 0.0002057587 time: 0.09516239166259766
# Iteration: 1120 loss: 0.0002056786 time: 0.10018444061279297
# Iteration: 1130 loss: 0.0002056194 time: 0.09852290153503418
# Iteration: 1140 loss: 0.0002055688 time: 0.10069465637207031
# Iteration: 1150 loss: 0.0002055244 time: 0.0978097915649414
# Iteration: 1160 loss: 0.0002054854 time: 0.09659576416015625
# Iteration: 1170 loss: 0.0002054523 time: 0.10051560401916504
# Iteration: 1180 loss: 0.0002054236 time: 0.10296034812927246
# Iteration: 1190 loss: 0.0002053992 time: 0.11077880859375
# Iteration: 1200 loss: 0.0002053783 time: 0.10666728019714355
# Iteration: 1210 loss: 0.0002053606 time: 0.09852766990661621
# Iteration: 1220 loss: 0.0002053456 time: 0.10091161727905273
# Iteration: 1230 loss: 0.0002053329 time: 0.10038375854492188
# Iteration: 1240 loss: 0.0002053223 time: 0.09912633895874023
# Iteration: 1250 loss: 0.0002053214 time: 0.10290217399597168
# Iteration: 1260 loss: 0.0002073745 time: 0.09551882743835449
# Iteration: 1270 loss: 0.0002062414 time: 0.09364628791809082
# Iteration: 1280 loss: 0.0002053869 time: 0.09708380699157715
# Iteration: 1290 loss: 0.0002053238 time: 0.10085868835449219
# Iteration: 1300 loss: 0.0002053513 time: 0.1038675308227539
# Iteration: 1310 loss: 0.0002053100 time: 0.1111454963684082
# Iteration: 1320 loss: 0.0002052886 time: 0.09206151962280273
# Iteration: 1330 loss: 0.0002052825 time: 0.10973668098449707
# Iteration: 1340 loss: 0.0002052799 time: 0.10781741142272949
# Iteration: 1350 loss: 0.0002052781 time: 0.10485076904296875
# Iteration: 1360 loss: 0.0002052766 time: 0.10881662368774414
# Iteration: 1370 loss: 0.0002052753 time: 0.10290718078613281
# Iteration: 1380 loss: 0.0002052742 time: 0.0975809097290039
# Iteration: 1390 loss: 0.0002052733 time: 0.11585354804992676
# Iteration: 1400 loss: 0.0002052726 time: 0.10765624046325684
# Iteration: 1410 loss: 0.0002052719 time: 0.1047053337097168
# Iteration: 1420 loss: 0.0002052714 time: 0.09925508499145508
# Iteration: 1430 loss: 0.0002052710 time: 0.10758209228515625
# Iteration: 1440 loss: 0.0002052706 time: 0.10100317001342773
# Iteration: 1450 loss: 0.0002052703 time: 0.09975838661193848
# Iteration: 1460 loss: 0.0002052700 time: 0.09770464897155762
# Iteration: 1470 loss: 0.0002052698 time: 0.09884238243103027
# Iteration: 1480 loss: 0.0002052696 time: 0.10398578643798828
# Iteration: 1490 loss: 0.0002052695 time: 0.10428643226623535
# Iteration: 1500 loss: 0.0002052693 time: 0.09534072875976562
# Iteration: 1510 loss: 0.0002052692 time: 0.09182953834533691
# Iteration: 1520 loss: 0.0002052691 time: 0.09277153015136719
# Iteration: 1530 loss: 0.0002052697 time: 0.09419703483581543
# Iteration: 1540 loss: 0.0002055753 time: 0.0991816520690918
# Iteration: 1550 loss: 0.0002057673 time: 0.09241819381713867
# Iteration: 1560 loss: 0.0002060607 time: 0.09268474578857422
# Iteration: 1570 loss: 0.0002054047 time: 0.09540343284606934
# Iteration: 1580 loss: 0.0002053523 time: 0.09082412719726562
# Iteration: 1590 loss: 0.0002052832 time: 0.09456276893615723
# Iteration: 1600 loss: 0.0002052787 time: 0.09758567810058594
# Iteration: 1610 loss: 0.0002052724 time: 0.09575891494750977
# Iteration: 1620 loss: 0.0002052690 time: 0.09482002258300781
# Iteration: 1630 loss: 0.0002052694 time: 0.10036230087280273
# Iteration: 1640 loss: 0.0002052688 time: 0.11715841293334961
# Iteration: 1650 loss: 0.0002052686 time: 0.1196296215057373
# Iteration: 1660 loss: 0.0002052686 time: 0.11585164070129395
# Iteration: 1670 loss: 0.0002052685 time: 0.10016012191772461
# Iteration: 1680 loss: 0.0002052685 time: 0.10288619995117188
# Iteration: 1690 loss: 0.0002052684 time: 0.10016703605651855
# Iteration: 1700 loss: 0.0002052684 time: 0.1024477481842041
# Iteration: 1710 loss: 0.0002052684 time: 0.10502839088439941
# Iteration: 1720 loss: 0.0002052684 time: 0.10342288017272949
# Iteration: 1730 loss: 0.0002052683 time: 0.10951948165893555
# Iteration: 1740 loss: 0.0002052683 time: 0.10640120506286621
# Iteration: 1750 loss: 0.0002052683 time: 0.1040201187133789
# Iteration: 1760 loss: 0.0002052683 time: 0.0960690975189209
# Iteration: 1770 loss: 0.0002052683 time: 0.10000348091125488
# Iteration: 1780 loss: 0.0002052683 time: 0.10094523429870605
# Iteration: 1790 loss: 0.0002052682 time: 0.10619378089904785
# Iteration: 1800 loss: 0.0002052682 time: 0.10766768455505371
# Iteration: 1810 loss: 0.0002052682 time: 0.09471893310546875
# Iteration: 1820 loss: 0.0002052682 time: 0.10128641128540039
# Iteration: 1830 loss: 0.0002052682 time: 0.1142721176147461
# Iteration: 1840 loss: 0.0002052682 time: 0.10900139808654785
# Iteration: 1850 loss: 0.0002052682 time: 0.1077573299407959
# Iteration: 1860 loss: 0.0002052682 time: 0.10187625885009766
# Iteration: 1870 loss: 0.0002052682 time: 0.09827160835266113
# Iteration: 1880 loss: 0.0002052682 time: 0.11092138290405273
# Iteration: 1890 loss: 0.0002052681 time: 0.10691070556640625
# Iteration: 1900 loss: 0.0002052681 time: 0.1124579906463623
# Iteration: 1910 loss: 0.0002052682 time: 0.09820008277893066
# Iteration: 1920 loss: 0.0002053403 time: 0.10477089881896973
# Iteration: 1930 loss: 0.0002079691 time: 0.12812256813049316
# Iteration: 1940 loss: 0.0002052766 time: 0.09415960311889648
# Iteration: 1950 loss: 0.0002057259 time: 0.11366462707519531
# Iteration: 1960 loss: 0.0002054074 time: 0.11393284797668457
# Iteration: 1970 loss: 0.0002052720 time: 0.11335611343383789
# Iteration: 1980 loss: 0.0002052786 time: 0.10914278030395508
# Iteration: 1990 loss: 0.0002052764 time: 0.1083674430847168
# Iteration: 2000 loss: 0.0002052687 time: 0.10650324821472168
# Iteration: 2010 loss: 0.0002052692 time: 0.10598945617675781
# Iteration: 2020 loss: 0.0002052685 time: 0.09737515449523926
# Iteration: 2030 loss: 0.0002052684 time: 0.125504732131958
# Iteration: 2040 loss: 0.0002052683 time: 0.1205453872680664
# Iteration: 2050 loss: 0.0002052682 time: 0.1110239028930664
# Iteration: 2060 loss: 0.0002052682 time: 0.10067892074584961
# Iteration: 2070 loss: 0.0002052682 time: 0.11155104637145996
# Iteration: 2080 loss: 0.0002052681 time: 0.10265350341796875
# Iteration: 2090 loss: 0.0002052681 time: 0.10905766487121582
# Iteration: 2100 loss: 0.0002052681 time: 0.10127711296081543
# Iteration: 2110 loss: 0.0002052681 time: 0.10625195503234863
# Iteration: 2120 loss: 0.0002052681 time: 0.10747861862182617
# Iteration: 2130 loss: 0.0002052681 time: 0.0920557975769043
# Iteration: 2140 loss: 0.0002052681 time: 0.09583687782287598
# Iteration: 2150 loss: 0.0002052681 time: 0.10203981399536133
# Iteration: 2160 loss: 0.0002052681 time: 0.1094517707824707
# Iteration: 2170 loss: 0.0002052680 time: 0.10271430015563965
# Iteration: 2180 loss: 0.0002052680 time: 0.10099315643310547
# Iteration: 2190 loss: 0.0002052680 time: 0.0965738296508789
# Iteration: 2200 loss: 0.0002052680 time: 0.10558843612670898
# Iteration: 2210 loss: 0.0002052680 time: 0.10738253593444824
# Iteration: 2220 loss: 0.0002052680 time: 0.0991659164428711
# Iteration: 2230 loss: 0.0002052680 time: 0.1141963005065918
# Iteration: 2240 loss: 0.0002052680 time: 0.10762190818786621
# Iteration: 2250 loss: 0.0002052680 time: 0.10283207893371582
# Iteration: 2260 loss: 0.0002052680 time: 0.10026931762695312
# Iteration: 2270 loss: 0.0002052680 time: 0.11088705062866211
# Iteration: 2280 loss: 0.0002052680 time: 0.10528731346130371
# Iteration: 2290 loss: 0.0002052680 time: 0.09697222709655762
# Iteration: 2300 loss: 0.0002052680 time: 0.10035443305969238
# Iteration: 2310 loss: 0.0002052680 time: 0.0967261791229248
# Iteration: 2320 loss: 0.0002052680 time: 0.10515308380126953
# Iteration: 2330 loss: 0.0002052680 time: 0.10567116737365723
# Iteration: 2340 loss: 0.0002052680 time: 0.1099088191986084
# Iteration: 2350 loss: 0.0002052680 time: 0.10419011116027832
# Iteration: 2360 loss: 0.0002052680 time: 0.10083961486816406
# Iteration: 2370 loss: 0.0002052680 time: 0.1051032543182373
# Iteration: 2380 loss: 0.0002052680 time: 0.11081671714782715
# Iteration: 2390 loss: 0.0002053047 time: 0.10645842552185059
# Iteration: 2400 loss: 0.0002109958 time: 0.11067652702331543
# Iteration: 2410 loss: 0.0002052878 time: 0.09011054039001465
# Iteration: 2420 loss: 0.0002054582 time: 0.10021615028381348
# Iteration: 2430 loss: 0.0002053799 time: 0.1171567440032959
# Iteration: 2440 loss: 0.0002053176 time: 0.09922266006469727
# Iteration: 2450 loss: 0.0002052903 time: 0.10118913650512695
# Iteration: 2460 loss: 0.0002052780 time: 0.09625053405761719
# Iteration: 2470 loss: 0.0002052720 time: 0.09075188636779785
# Iteration: 2480 loss: 0.0002052693 time: 0.10243773460388184
# Iteration: 2490 loss: 0.0002052684 time: 0.10259723663330078
# Iteration: 2500 loss: 0.0002052683 time: 0.10985255241394043
# Iteration: 2510 loss: 0.0002052682 time: 0.09908175468444824
# Iteration: 2520 loss: 0.0002052682 time: 0.09816908836364746
# Iteration: 2530 loss: 0.0002052681 time: 0.10632777214050293
# Iteration: 2540 loss: 0.0002052681 time: 0.09772682189941406
# Iteration: 2550 loss: 0.0002052681 time: 0.09461688995361328
# Iteration: 2560 loss: 0.0002052680 time: 0.10114216804504395
# Iteration: 2570 loss: 0.0002052680 time: 0.09379124641418457
# Iteration: 2580 loss: 0.0002052680 time: 0.09625744819641113
# Iteration: 2590 loss: 0.0002052680 time: 0.11178350448608398
# Iteration: 2600 loss: 0.0002052680 time: 0.11640095710754395
# Iteration: 2610 loss: 0.0002052680 time: 0.09956669807434082
# Iteration: 2620 loss: 0.0002052680 time: 0.09850955009460449
# Iteration: 2630 loss: 0.0002052680 time: 0.09088754653930664
# Iteration: 2640 loss: 0.0002052680 time: 0.1035621166229248
# Iteration: 2650 loss: 0.0002052680 time: 0.09938240051269531
# Iteration: 2660 loss: 0.0002052680 time: 0.09372329711914062
# Iteration: 2670 loss: 0.0002052680 time: 0.10142946243286133
# Iteration: 2680 loss: 0.0002052680 time: 0.09549927711486816
# Iteration: 2690 loss: 0.0002052680 time: 0.09671783447265625
# Iteration: 2700 loss: 0.0002052680 time: 0.10754919052124023
# Iteration: 2710 loss: 0.0002052680 time: 0.09869050979614258
# Iteration: 2720 loss: 0.0002052680 time: 0.0972292423248291
# Iteration: 2730 loss: 0.0002052680 time: 0.10471558570861816
# Iteration: 2740 loss: 0.0002052680 time: 0.09807753562927246
# Iteration: 2750 loss: 0.0002052680 time: 0.0979163646697998
# Iteration: 2760 loss: 0.0002052680 time: 0.09878230094909668
# Iteration: 2770 loss: 0.0002052679 time: 0.09460711479187012
# Iteration: 2780 loss: 0.0002052679 time: 0.09481048583984375
# Iteration: 2790 loss: 0.0002052679 time: 0.10553503036499023
# Iteration: 2800 loss: 0.0002052679 time: 0.08973932266235352
# Iteration: 2810 loss: 0.0002052679 time: 0.08767247200012207
# Iteration: 2820 loss: 0.0002052679 time: 0.10027408599853516
# Iteration: 2830 loss: 0.0002052679 time: 0.0997931957244873
# ...
# Iteration: 4220 loss: 0.0002052679 time: 0.09974503517150879
# Iteration: 4230 loss: 0.0002052679 time: 0.0993964672088623
# Iteration: 4240 loss: 0.0002052679 time: 0.09766864776611328
# Iteration: 4250 loss: 0.0002053138 time: 0.11173057556152344
# Iteration: 4260 loss: 0.0002065983 time: 0.10001516342163086
# Iteration: 4270 loss: 0.0002056540 time: 0.10154867172241211
# Iteration: 4280 loss: 0.0002053145 time: 0.10724639892578125
# Iteration: 4290 loss: 0.0002053064 time: 0.11056065559387207
# Iteration: 4300 loss: 0.0002052763 time: 0.149322509765625
# Iteration: 4310 loss: 0.0002052701 time: 0.1168832778930664
# Iteration: 4320 loss: 0.0002052701 time: 0.10196423530578613
# Iteration: 4330 loss: 0.0002052688 time: 0.10382652282714844
# Iteration: 4340 loss: 0.0002052681 time: 0.09775543212890625
# Iteration: 4350 loss: 0.0002052680 time: 0.10252094268798828
# Iteration: 4360 loss: 0.0002052680 time: 0.09843587875366211
# Iteration: 4370 loss: 0.0002052679 time: 0.10458564758300781
# Iteration: 4380 loss: 0.0002052679 time: 0.10146594047546387
# Iteration: 4390 loss: 0.0002052679 time: 0.10366559028625488
# Iteration: 4400 loss: 0.0002052679 time: 0.1040959358215332
# Iteration: 4410 loss: 0.0002052679 time: 0.10595393180847168
# Iteration: 4420 loss: 0.0002052679 time: 0.09598207473754883
# Iteration: 4430 loss: 0.0002052683 time: 0.09729981422424316
# Iteration: 4440 loss: 0.0002052928 time: 0.0961923599243164
# Iteration: 4450 loss: 0.0002069814 time: 0.10761499404907227
# Iteration: 4460 loss: 0.0002058379 time: 0.09924149513244629
# Iteration: 4470 loss: 0.0002054996 time: 0.10079574584960938
# Iteration: 4480 loss: 0.0002053225 time: 0.1008608341217041
# Iteration: 4490 loss: 0.0002052757 time: 0.09890365600585938
# Iteration: 4500 loss: 0.0002052682 time: 0.1022481918334961
# Iteration: 4510 loss: 0.0002052695 time: 0.1103811264038086
# Iteration: 4520 loss: 0.0002052694 time: 0.10068941116333008
# Iteration: 4530 loss: 0.0002052681 time: 0.09697270393371582
# Iteration: 4540 loss: 0.0002052680 time: 0.09862041473388672
# Iteration: 4550 loss: 0.0002052680 time: 0.10176992416381836
# Iteration: 4560 loss: 0.0002052679 time: 0.09931516647338867
# Iteration: 4570 loss: 0.0002052679 time: 0.1036534309387207
# Iteration: 4580 loss: 0.0002052679 time: 0.1023550033569336
# Iteration: 4590 loss: 0.0002052679 time: 0.09895014762878418
# Iteration: 4600 loss: 0.0002052679 time: 0.10543584823608398
# Iteration: 4610 loss: 0.0002052679 time: 0.10032486915588379
# Iteration: 4620 loss: 0.0002052679 time: 0.09381985664367676
# Iteration: 4630 loss: 0.0002052679 time: 0.09982180595397949
# Iteration: 4640 loss: 0.0002052679 time: 0.11079144477844238
# Iteration: 4650 loss: 0.0002052679 time: 0.1077427864074707
# Iteration: 4660 loss: 0.0002052679 time: 0.09053850173950195
# Iteration: 4670 loss: 0.0002052679 time: 0.09901738166809082
# Iteration: 4680 loss: 0.0002052679 time: 0.09943151473999023
# Iteration: 4690 loss: 0.0002052679 time: 0.09136557579040527
# Iteration: 4700 loss: 0.0002052679 time: 0.10597896575927734
# Iteration: 4710 loss: 0.0002052680 time: 0.10149407386779785
# Iteration: 4720 loss: 0.0002052778 time: 0.10167217254638672
# Iteration: 4730 loss: 0.0002070496 time: 0.10043811798095703
# Iteration: 4740 loss: 0.0002059355 time: 0.10248017311096191
# Iteration: 4750 loss: 0.0002054097 time: 0.10072731971740723
# Iteration: 4760 loss: 0.0002052790 time: 0.10204672813415527
# Iteration: 4770 loss: 0.0002052845 time: 0.10422015190124512
# Iteration: 4780 loss: 0.0002052793 time: 0.10329055786132812
# Iteration: 4790 loss: 0.0002052729 time: 0.10732364654541016
# Iteration: 4800 loss: 0.0002052698 time: 0.10297369956970215
# Iteration: 4810 loss: 0.0002052685 time: 0.10161972045898438
# Iteration: 4820 loss: 0.0002052681 time: 0.10189223289489746
# Iteration: 4830 loss: 0.0002052680 time: 0.09995174407958984
# Iteration: 4840 loss: 0.0002052680 time: 0.10248684883117676
# Iteration: 4850 loss: 0.0002052680 time: 0.1094675064086914
# Iteration: 4860 loss: 0.0002052679 time: 0.09837031364440918
# Iteration: 4870 loss: 0.0002052679 time: 0.10628676414489746
# Iteration: 4880 loss: 0.0002052679 time: 0.10454511642456055
# Iteration: 4890 loss: 0.0002052679 time: 0.10715317726135254
# Iteration: 4900 loss: 0.0002052679 time: 0.11391854286193848
# Iteration: 4910 loss: 0.0002052679 time: 0.10519862174987793
# Iteration: 4920 loss: 0.0002052679 time: 0.10609984397888184
# Iteration: 4930 loss: 0.0002052679 time: 0.09794425964355469
# Iteration: 4940 loss: 0.0002052679 time: 0.1085355281829834
# Iteration: 4950 loss: 0.0002052679 time: 0.1072700023651123
# Iteration: 4960 loss: 0.0002052679 time: 0.11205816268920898
# Iteration: 4970 loss: 0.0002052679 time: 0.10549116134643555
# Iteration: 4980 loss: 0.0002052679 time: 0.10765552520751953
# Iteration: 4990 loss: 0.0002052679 time: 0.11053586006164551
# Iteration: 5000 loss: 0.0002052679 time: 0.12287592887878418
# -->mesh :
#      n_triangles :  256
#      n_vertices  :  145
#      n_edges     :  400
#      h_max           :  0.125
#      h_min           :  0.08838834764831845
# -->test_fun      :
#      order       :  2
#      dof         :  481
# Iteration: 0 loss: 0.0000437142 time: 107.52626490592957
# Iteration: 10 loss: 0.0000378435 time: 0.17978119850158691
# Iteration: 20 loss: 0.0000368864 time: 0.19070863723754883
# Iteration: 30 loss: 0.0000356682 time: 0.18279290199279785
# Iteration: 40 loss: 0.0000352660 time: 0.1932992935180664
# Iteration: 50 loss: 0.0000351018 time: 0.1870427131652832
# Iteration: 60 loss: 0.0000350341 time: 0.18766570091247559
# Iteration: 70 loss: 0.0000349860 time: 0.19754815101623535
# Iteration: 80 loss: 0.0000349399 time: 0.19253778457641602
# Iteration: 90 loss: 0.0000349023 time: 0.19402670860290527
# Iteration: 100 loss: 0.0000348693 time: 0.20895051956176758
# Iteration: 110 loss: 0.0000348371 time: 0.18900752067565918
# Iteration: 120 loss: 0.0000348047 time: 0.18473601341247559
# Iteration: 130 loss: 0.0000347715 time: 0.17299175262451172
# Iteration: 140 loss: 0.0000347370 time: 0.21052956581115723
# Iteration: 150 loss: 0.0000347008 time: 0.26784348487854004
# Iteration: 160 loss: 0.0000346625 time: 0.2270188331604004
# Iteration: 170 loss: 0.0000346217 time: 0.23108458518981934
# Iteration: 180 loss: 0.0000345776 time: 0.21270227432250977
# Iteration: 190 loss: 0.0000345296 time: 0.19792652130126953
# Iteration: 200 loss: 0.0000344770 time: 0.19164538383483887
# Iteration: 210 loss: 0.0000344185 time: 0.14992237091064453
# Iteration: 220 loss: 0.0000343532 time: 0.16574645042419434
# Iteration: 230 loss: 0.0000342796 time: 0.16659855842590332
# Iteration: 240 loss: 0.0000341960 time: 0.15422892570495605
# Iteration: 250 loss: 0.0000341005 time: 0.1824655532836914
# Iteration: 260 loss: 0.0000339909 time: 0.16667675971984863
# Iteration: 270 loss: 0.0000338649 time: 0.16311430931091309
# Iteration: 280 loss: 0.0000337200 time: 0.15566635131835938
# Iteration: 290 loss: 0.0000335540 time: 0.1652381420135498
# Iteration: 300 loss: 0.0000333659 time: 0.16084504127502441
# Iteration: 310 loss: 0.0000331561 time: 0.1517477035522461
# Iteration: 320 loss: 0.0000329281 time: 0.1725156307220459
# Iteration: 330 loss: 0.0000326894 time: 0.16053152084350586
# Iteration: 340 loss: 0.0000324515 time: 0.16364431381225586
# Iteration: 350 loss: 0.0000322272 time: 0.15785598754882812
# Iteration: 360 loss: 0.0000320269 time: 0.2083888053894043
# Iteration: 370 loss: 0.0000318540 time: 0.17444968223571777
# Iteration: 380 loss: 0.0000317050 time: 0.1979665756225586
# Iteration: 390 loss: 0.0000315729 time: 0.1897869110107422
# Iteration: 400 loss: 0.0000314508 time: 0.1858370304107666
# Iteration: 410 loss: 0.0000313341 time: 0.1850264072418213
# Iteration: 420 loss: 0.0000312195 time: 0.2029259204864502
# Iteration: 430 loss: 0.0000311047 time: 0.1930372714996338
# Iteration: 440 loss: 0.0000309882 time: 0.18362927436828613
# Iteration: 450 loss: 0.0000308688 time: 0.16517853736877441
# Iteration: 460 loss: 0.0000307455 time: 0.1895453929901123
# Iteration: 470 loss: 0.0000306178 time: 0.16274189949035645
# Iteration: 480 loss: 0.0000304853 time: 0.21351909637451172
# Iteration: 490 loss: 0.0000303478 time: 0.2564816474914551
# Iteration: 500 loss: 0.0000302053 time: 0.18008017539978027
# Iteration: 510 loss: 0.0000300576 time: 0.20017790794372559
# Iteration: 520 loss: 0.0000299042 time: 0.20020461082458496
# Iteration: 530 loss: 0.0000297428 time: 0.19203710556030273
# Iteration: 540 loss: 0.0000295668 time: 0.22823572158813477
# Iteration: 550 loss: 0.0000293607 time: 0.18669915199279785
# Iteration: 560 loss: 0.0000290947 time: 0.2148904800415039
# Iteration: 570 loss: 0.0000287373 time: 0.1787090301513672
# Iteration: 580 loss: 0.0000283026 time: 0.22167539596557617
# Iteration: 590 loss: 0.0000278353 time: 0.29196619987487793
# Iteration: 600 loss: 0.0000273302 time: 0.273728609085083
# Iteration: 610 loss: 0.0000267896 time: 0.21683764457702637
# Iteration: 620 loss: 0.0000262232 time: 0.28363537788391113
# Iteration: 630 loss: 0.0000256495 time: 0.19382238388061523
# Iteration: 640 loss: 0.0000251258 time: 0.2535548210144043
# Iteration: 650 loss: 0.0000247256 time: 0.23151946067810059
# Iteration: 660 loss: 0.0000244611 time: 0.20542383193969727
# Iteration: 670 loss: 0.0000242704 time: 0.18901586532592773
# Iteration: 680 loss: 0.0000241085 time: 0.2065143585205078
# Iteration: 690 loss: 0.0000239662 time: 0.23280000686645508
# Iteration: 700 loss: 0.0000238384 time: 0.25168824195861816
# Iteration: 710 loss: 0.0000237200 time: 0.29851627349853516
# Iteration: 720 loss: 0.0000236076 time: 0.19945406913757324
# Iteration: 730 loss: 0.0000234988 time: 0.21995329856872559
# Iteration: 740 loss: 0.0000233924 time: 0.24233222007751465
# Iteration: 750 loss: 0.0000232880 time: 0.2264697551727295
# Iteration: 760 loss: 0.0000231856 time: 0.1948251724243164
# Iteration: 770 loss: 0.0000230860 time: 0.1804180145263672
# Iteration: 780 loss: 0.0000229896 time: 0.17582464218139648
# Iteration: 790 loss: 0.0000228970 time: 0.21520614624023438
# Iteration: 800 loss: 0.0000228084 time: 0.22493433952331543
# Iteration: 810 loss: 0.0000227235 time: 0.21991515159606934
# Iteration: 820 loss: 0.0000226787 time: 0.18363499641418457
# Iteration: 830 loss: 0.0000226161 time: 0.18419671058654785
# Iteration: 840 loss: 0.0000225226 time: 0.1746830940246582
# Iteration: 850 loss: 0.0000224460 time: 0.20506596565246582
# Iteration: 860 loss: 0.0000223741 time: 0.24580812454223633
# Iteration: 870 loss: 0.0000223085 time: 0.2314774990081787
# Iteration: 880 loss: 0.0000222412 time: 0.22107195854187012
# Iteration: 890 loss: 0.0000221745 time: 0.21670889854431152
# Iteration: 900 loss: 0.0000221075 time: 0.20810174942016602
# Iteration: 910 loss: 0.0000220424 time: 0.20237088203430176
# Iteration: 920 loss: 0.0000219785 time: 0.18893170356750488
# Iteration: 930 loss: 0.0000219557 time: 0.22093486785888672
# Iteration: 940 loss: 0.0000218703 time: 0.2188122272491455
# Iteration: 950 loss: 0.0000218189 time: 0.18950676918029785
# Iteration: 960 loss: 0.0000217613 time: 0.19188213348388672
# Iteration: 970 loss: 0.0000217075 time: 0.1764049530029297
# Iteration: 980 loss: 0.0000216541 time: 0.1747746467590332
# Iteration: 990 loss: 0.0000218788 time: 0.17087721824645996
# Iteration: 1000 loss: 0.0000215680 time: 0.16826891899108887
# Iteration: 1010 loss: 0.0000215196 time: 0.17241954803466797
# Iteration: 1020 loss: 0.0000214799 time: 0.18423962593078613
# Iteration: 1030 loss: 0.0000214241 time: 0.19956493377685547
# Iteration: 1040 loss: 0.0000213778 time: 0.18981194496154785
# Iteration: 1050 loss: 0.0000213332 time: 0.22813844680786133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [254], line 27
#      25 model = restart_model()
#      26 vp=VPINN(pb,params,fine_mesh,False,coarse_mesh,model)
# ---> 27 history=vp.train(5000, 0.001)
#      30 semi_H1_err = semi_H1_error(xy, w)
#      31 L2_error_ = L2_error(xy, w)
#
# File ~/IVPINN/absolute_madness/VPINN_tri_final.py:574, in VPINN.train(self, iter, LR, bc_model)
#     571 if self.n_test > 1:
#     572     self.sum_of_vectors_edges.assign(tf.zeros_like(self.sum_of_vectors_edges))
# --> 574 loss = self.gradient_descent()  #add other losses
#     575 if i % 10 == 0:
#     576     elapsed = time.time() - start_time
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
h = np.array(h)
H1 = np.array(H1)
L2 = np.array(L2)
semi = np.array(semi)

# %%
# slope_H1, intercept_H1 = np.polyfit(h, H1, 1)
# slope_L2, intercept_L2 = np.polyfit(h, L2, 1)

#coeffs = np.polyfit(np.log10(h), np.log10(H1), 1)
#polynomial = np.poly1d(coeffs)
#log10_H1_fit = polynomial(np.log10(h))

#print(f"H1 rate: {coeffs[0]}")

coeffs = np.polyfit(np.log10(h), np.log10(semi), 1)
polynomial = np.poly1d(coeffs)
log10_semi_H1_fit = polynomial(np.log10(h))

print(f"semi H1 rate: {coeffs[0]}")

coeffs = np.polyfit(np.log10(h), np.log10(L2), 1)
polynomial = np.poly1d(coeffs)
log10_L2_fit = polynomial(np.log10(h))

print(f"L2 rate: {coeffs[0]}")
# Out:
# semi H1 rate: 1.6992632167854644
# L2 rate: 3.4568804074421466

# %%
#plt.loglog(h, H1, marker='o', label='H1')
plt.loglog(h, L2, marker='o', label='L2')
plt.loglog(h, semi, marker='o', label='semi')
plt.loglog(h, 10**log10_semi_H1_fit,label='semi H1 reg')
plt.loglog(h, 10**log10_L2_fit,label='L2 reg ')
plt.loglog(h, h, linestyle=':', label='h1')
plt.loglog(h, h*h, linestyle=':', label='h2')
plt.loglog(h, h*h*h, linestyle=':', label='h3')
plt.loglog(h, h*h*h*h, linestyle=':', label='h4')
plt.grid()
plt.legend()

# %%
#plt.loglog(h, H1, marker='o', label='H1')
h = 4*h
plt.loglog(h, L2, marker='o', label='L2')
plt.loglog(h, semi, marker='o', label='semi')
plt.loglog(h, 10**log10_semi_H1_fit,label='semi H1 reg')
plt.loglog(h, 10**log10_L2_fit,label='L2 reg ')
plt.loglog(h, h, linestyle=':', label='h1')
plt.loglog(h, h*h, linestyle=':', label='h2')
plt.loglog(h, h*h*h, linestyle=':', label='h3')
plt.loglog(h, h*h*h*h, linestyle=':', label='h4')
plt.grid()
plt.legend()
