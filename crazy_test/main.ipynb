# %%
from mesh import *

from VPINN_tri_final import *

from PROBDEF import PROBDEF

#TODO: change all types
#TODO: bound error after reading the paper 

import os; os.environ['CUDA_VISIBLE_DEVICES'] = '-1';
# Out:
# 2023-11-28 12:44:00.136100: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 12:44:01.892488: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# my_types lib imported
#
# generate mesh lib imported
#
# interpolator_lib imported
#
# settings_lib imported

# %%
initializer=tf.keras.initializers.GlorotUniform(seed=69)


domain=((0,0),(1,0),(1,1),(0,1))

mesh=generate_mesh(domain,0.01)

# %%
tfk=tf.keras
tfkl=tf.keras.layers

# %%
#glorot uniform is the key 
model = tfk.models.Sequential()
model.add(tf.keras.Input(shape=(2,),dtype=tf.float64))
model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
model.add(tf.keras.layers.Dense(1,activation='linear',kernel_initializer=initializer,dtype=tf_type,use_bias=True))
# Out:
# 2023-11-28 12:44:06.173860: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
print(model.summary())
#print(model.input_shape)
#print(model.output_shape)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 371
# Trainable params: 371
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
N_tests = 2
N_elements = [5, 5]

pb=PROBDEF()

params = {'scheme': 'VPINNs',
            'NN_struct': [2] + [5] * 3 + [1],
            'var_form': 1,
            'n_elements': tuple(N_elements),
            'n_test': [N_elements[0]*[N_tests], N_elements[1]*[N_tests]],
            'n_quad': 50,
            'n_bound': 80, # for every edge 
            'n_residual': 100,
            'domain': ((0.0, 1.0), (0.0, 1.0)),
            'Opt_Niter': 15000 + 1,
            'delta_test': 0.01,
            'N_test':N_tests}

# %%
vp=VPINN(pb,params,mesh,model)

from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

N = 50
x=np.linspace(0,1,N,dtype=np.float32)
XX,YY = np.meshgrid(x,x)


basis1 = lambda x, y: 1 - 3*x + 2*x*x - 3*y + 4*x*y + 2*y*y
basis2 = lambda x, y: 1 + 4*x - 4*x*x - 4*x*y
z = basis2(XX, YY)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(XX, YY, z, rstride=1, cstride=1, cmap=cm.coolwarm,
    linewidth=0, antialiased=False)
# ax.set_zlim(-1.01, 0)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('NN solution')
# Out:
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# -->mesh :
#      n_triangles :  150
#      n_vertices  :  88
#      n_edges     :  237
#      h_max           :  0.25
#      h_min           :  0.0895721626833764
# -->test_fun      :
#      order       :  2
#      dof         :  277
# Text(0.5, 0.92, 'NN solution')

# %%
starting, _ = vp.calc_residuals()

# %%
#print(find_h(mesh)) #biggest and smaller of the edges 


x = vp.mesh['vertices'][:,0]
y = vp.mesh['vertices'][:,1]


plt.figure(figsize=(8, 6))
# plt.triplot(
#     x,
#     y
# )
scatter = plt.scatter(x, y, c=starting, cmap='inferno', marker='o')

plt.colorbar(scatter, label='Function Value')
plt.title('Heatmap from Point Evaluations')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
iterations = range(0, len(history) * 10, 10)  # Assuming losses are provided every 10 iterations

plt.plot(iterations, history, marker='*',color='green',linewidth=1)
plt.title('Loss Function Over Iterations')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.grid()
plt.show()

# %%
plt.semilogy(iterations, history,linewidth=1)
plt.title('Loss Function Over Iterations (semilog scale)')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.grid()
plt.show()

# %%
#for the plots 

x=np.linspace(0,1,100,dtype=np.float32)

def u_exact(x,y):

    return np.cos(np.pi*(x+0.5))*np.sin(np.pi*y)


eval_exact=[u_exact(x[i],0.5) for i in range(len(x))]

eval_net=[vp.u_NN_BC(x[i],0.5) for i in range(len(x))]

eval_exact=np.array(eval_exact)
eval_net=np.array(eval_net)

# %%
plt.figure(figsize=(8, 6))  # Set the figure size

# Plot the data
plt.plot(x, eval_net, label='eval_net', linestyle='-', marker='o', color='b')
plt.plot(x, eval_exact, label='eval_exact', linestyle='--', marker='x', color='r')
plt.grid()
plt.legend()

#if you want reproducibility put a seed

# %%
## Add surface plot
N = 50
x=np.linspace(0,1,N,dtype=np.float32)
XX,YY = np.meshgrid(x,x)
xx = XX.flatten()
yy = YY.flatten()

X = np.vstack((xx,yy)).transpose()
Z = [vp.u_NN_BC(x[0],x[1]) for x in X]

z = np.array(Z).flatten().reshape((N,N))

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(XX, YY, z, rstride=1, cstride=1, cmap=cm.coolwarm,
    linewidth=0, antialiased=False)
# ax.set_zlim(-1.01, 0)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('NN solution')
# Out:
# Text(0.5, 0.92, 'NN solution')

# %%
#integration
from scipy.integrate import dblquad
integral,error=dblquad(lambda x,y: (u_exact(x,y)-vp.u_NN_BC(x,y))**2, 0.0, 1.0,0.0, 1.0)

L2_error=np.sqrt(integral)
print(L2_error,error)


def L2_error(x, y):

    u_ex = lambda x, y: tf.cos(np.pi*(x+0.5))*tf.sin(np.pi*y)

    # Find the exact solution
    u_ex = u_ex(x, y)

    # Find the NN solution
    u_NN = vp.u_NN_BC(x, y)

    # Find the difference between exact and NN 
    return (u_ex - u_NN)**2

L2_2, int_error_L2 = dblquad(L2_error, 0.0, 1.0, 0.0, 1.0)
L2_error=np.sqrt(L2_2)
# Out:
# 0.0014760758037754883 1.0483241605676685e-11

# %%
x = np.linspace(0, 1, 150, dtype=np.float64)
x, y = np.meshgrid(x,x)

u_ex_dx = lambda x, y: -np.pi*tf.sin(np.pi*(x + 0.5))*tf.sin(np.pi*y)
u_ex_dy = lambda x, y: np.pi*tf.cos(np.pi*(x + 0.5))*tf.cos(np.pi*y)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(x, y, u_ex_dx(x,y), rstride=1, cstride=1, cmap=cm.coolwarm,
    linewidth=0, antialiased=False)
# ax.set_zlim(-1.01, 0)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('NN dx')
plt.show()

# %%
def semi_H1_error(x, y):

    u_ex_dx = lambda x, y: -np.pi*tf.sin(np.pi*(x + 0.5))*tf.sin(np.pi*y)
    u_ex_dy = lambda x, y: np.pi*tf.cos(np.pi*(x + 0.5))*tf.cos(np.pi*y)

    # Find the gradient of the exact solution
    grad_ex = np.reshape(np.vstack([u_ex_dx(x, y), u_ex_dy(x, y)]), (-1, 2))

    # Find the gradient of the NN solution
    grad_NN = vp.eval_grad_NN_BC(tf.reshape(tf.stack([x,y]), (-1,2)))

    # Find the difference between exact and NN 
    pw_diff = grad_ex - grad_NN

    # Return dx_error^2 + dy_error^2
    return pw_diff[:,0]*pw_diff[:,0] + pw_diff[:,1]*pw_diff[:,1]

semi_H1_err2, int_error_semi_H1 = dblquad(semi_H1_error, 0.0, 1.0, 0.0, 1.0, epsabs=5E-6)
semi_H1_err = np.sqrt(semi_H1_err2)
H1_err = np.sqrt(L2_error**2 + semi_H1_err**2)

print(f"L2 error: {L2_error} ({int_error_L2})")
print(f"semi H1 error: {semi_H1_err} ({int_error_semi_H1})")
print(f"H1 error: {H1_err}")
# Out:
# L2 error: 0.0014760718391008127 (2.878742580723998e-10)
# semi H1 error: 0.017124496900143324 (2.479018099174727e-08)
# H1 error: 0.017187995291982273

# %%
def restart_model():
    model = tfk.models.Sequential()
    model.add(tf.keras.Input(shape=(2,),dtype=tf.float64))
    model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tfkl.Dense(10, activation='tanh',kernel_initializer=initializer,dtype=tf_type,bias_initializer=initializer))
    model.add(tf.keras.layers.Dense(1,activation='linear',kernel_initializer=initializer,dtype=tf_type,use_bias=True))
    return model

H1 = []
L2 = []
semi = []
h = []
for refinement in [0.5, 0.2, 0.1, 0.075, 0.05, 0.025, 0.01, 0.008, 0.005, 0.003]:
    model = restart_model()
    mesh=generate_mesh(domain,refinement)
    vp=VPINN(pb,params,mesh,model)
    history=vp.train(1000, 0.001)

    integral,error=dblquad(lambda x,y: (u_exact(x,y)-vp.u_NN_BC(x,y))**2, 0.0, 1.0,0.0, 1.0)

    L2_error=np.sqrt(integral)

    semi_H1_err2, int_error_semi_H1 = dblquad(semi_H1_error, 0.0, 1.0, 0.0, 1.0, epsabs=5E-6)
    semi_H1_err = np.sqrt(semi_H1_err2)
    H1_err = np.sqrt(L2_error**2 + semi_H1_err**2)

    H1.append(H1_err)
    semi.append(semi_H1_err)
    L2.append(L2_error)
    a, b = find_hs(mesh)
    h.append(0.5*a + 0.5*b)
# Out:
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# -->mesh :
#      n_triangles :  2
#      n_vertices  :  4
#      n_edges     :  5
#      h_max           :  1.4142135623730951
#      h_min           :  1.0
# -->test_fun      :
#      order       :  2
#      dof         :  1
# 2023-11-28 03:05:00.993510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_2/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_2/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_2/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_2/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:00.998954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/g
# Iteration: 800 loss: 0.0000000000 time: 0.03803849220275879
# Iteration: 810 loss: 0.0000000000 time: 0.0392909049987793
# Iteration: 820 loss: 0.0000000000 time: 0.036692142486572266
# Iteration: 830 loss: 0.0000000000 time: 0.0413203239440918
# Iteration: 840 loss: 0.0000000000 time: 0.03900647163391113
# Iteration: 850 loss: 0.0000000000 time: 0.04043221473693848
# Iteration: 860 loss: 0.0000000000 time: 0.0372614860534668
# Iteration: 870 loss: 0.0000000000 time: 0.04336380958557129
# Iteration: 880 loss: 0.0000000000 time: 0.03890514373779297
# Iteration: 890 loss: 0.0000000000 time: 0.0411379337310791
# Iteration: 900 loss: 0.0000000000 time: 0.04805278778076172
# Iteration: 910 loss: 0.0000000000 time: 0.039972782135009766
# Iteration: 920 loss: 0.0000000000 time: 0.04520153999328613
# Iteration: 930 loss: 0.0000000000 time: 0.039893388748168945
# Iteration: 940 loss: 0.0000000000 time: 0.045581817626953125
# Iteration: 950 loss: 0.0000000000 time: 0.04326987266540527
# Iteration: 960 loss: 0.0000000000 time: 0.04524111747741699
# Iteration: 970 loss: 0.0000000000 time: 0.051518917083740234
# Iteration: 980 loss: 0.0000000000 time: 0.039812564849853516
# Iteration: 990 loss: 0.0000000000 time: 0.041733741760253906
# Iteration: 1000 loss: 0.0000000000 time: 0.04588580131530762
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# -->mesh :
#      n_triangles :  8
#      n_vertices  :  9
#      n_edges     :  16
#      h_max           :  0.7071067811865476
#      h_min           :  0.5
# -->test_fun      :
#      order       :  2
#      dof         :  9
# 2023-11-28 03:05:13.068742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_2/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_2/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_2/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_2/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:13.071960: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_3/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_3/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_3/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_3/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:13.076656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:13.078785: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_1/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_1/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_1/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_1/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:13.228399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2}}]]
# 2023-11-28 03:05:13.228559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_5' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_5}}]]
# 2023-11-28 03:05:13.228652: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8}}]]
# 2023-11-28 03:05:13.228831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11}}]]
# 2023-11-28 03:05:13.500000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78}}]]
# 2023-11-28 03:05:13.500135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_112' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_112}}]]
# 2023-11-28 03:05:13.500199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_148' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_148}}]]
# 2023-11-28 03:05:13.500351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_183' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_183}}]]
# 2023-11-28 03:05:13.500442: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_218' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_218}}]]
# 2023-11-28 03:05:13.500541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251}}]]
# 2023-11-28 03:05:13.500626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_272' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_272}}]]
# 2023-11-28 03:05:13.500740: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_283' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_283}}]]
# 2023-11-28 03:05:13.500843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_288' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_288}}]]
# 2023-11-28 03:05:13.500992: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall
# Iteration: 930 loss: 0.0365416133 time: 0.06313014030456543
# Iteration: 940 loss: 0.0355286436 time: 0.062021732330322266
# Iteration: 950 loss: 0.0345111798 time: 0.06441593170166016
# Iteration: 960 loss: 0.0334864392 time: 0.06100964546203613
# Iteration: 970 loss: 0.0324511401 time: 0.057189226150512695
# Iteration: 980 loss: 0.0314015765 time: 0.0661463737487793
# Iteration: 990 loss: 0.0303337136 time: 0.07107281684875488
# Iteration: 1000 loss: 0.0292433039 time: 0.06995153427124023
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# basis:
# basis function number :  1
#
# 1 x^0 y^0 -3 x^1 y^0 2 x^2 y^0 -3 x^0 y^1 4 x^1 y^1 2 x^0 y^2
#
# basis function number :  2
#
# 0 x^0 y^0 4 x^1 y^0 -4 x^2 y^0 0 x^0 y^1 -4 x^1 y^1 0 x^0 y^2
#
# basis function number :  3
#
# 0 x^0 y^0 -1 x^1 y^0 2 x^2 y^0 0 x^0 y^1 0 x^1 y^1 0 x^0 y^2
#
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 4 x^0 y^1 -4 x^1 y^1 -4 x^0 y^2
#
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 0 x^0 y^1 4 x^1 y^1 0 x^0 y^2
#
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^2 y^0 -1 x^0 y^1 0 x^1 y^1 2 x^0 y^2
#
# basis :
# d1x
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  1
#
# -3 x^0 y^0 4 x^1 y^0 4 x^0 y^1
#
#
# d1x
# basis function number :  2
#
# 4 x^0 y^0 -8 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  2
#
# 0 x^0 y^0 -4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  3
#
# -1 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  3
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  4
#
# 0 x^0 y^0 0 x^1 y^0 -4 x^0 y^1
#
# d1y
# basis function number :  4
#
# 4 x^0 y^0 -4 x^1 y^0 -8 x^0 y^1
#
#
# d1x
# basis function number :  5
#
# 0 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
# d1y
# basis function number :  5
#
# 0 x^0 y^0 4 x^1 y^0 0 x^0 y^1
#
#
# d1x
# basis function number :  6
#
# 0 x^0 y^0 0 x^1 y^0 0 x^0 y^1
#
# d1y
# basis function number :  6
#
# -1 x^0 y^0 0 x^1 y^0 4 x^0 y^1
#
#
# basis :
# d2x
# basis function number :  1
#
# 4 x^0 y^0
#
# d2y
# basis function number :  1
#
# 4 x^0 y^0
#
#
# d2x
# basis function number :  2
#
# -8 x^0 y^0
#
# d2y
# basis function number :  2
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  3
#
# 4 x^0 y^0
#
# d2y
# basis function number :  3
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  4
#
# 0 x^0 y^0
#
# d2y
# basis function number :  4
#
# -8 x^0 y^0
#
#
# d2x
# basis function number :  5
#
# 0 x^0 y^0
#
# d2y
# basis function number :  5
#
# 0 x^0 y^0
#
#
# d2x
# basis function number :  6
#
# 0 x^0 y^0
#
# d2y
# basis function number :  6
#
# 4 x^0 y^0
#
#
# degree =  2  , local dof =  6  internal dof =  0  points inside each edge =  1
# [[0 0]
#  [1 0]
#  [0 1]
#  [1/2 0]
#  [1/2 1/2]
#  [0 1/2]]
# -->mesh :
#      n_triangles :  16
#      n_vertices  :  13
#      n_edges     :  28
#      h_max           :  0.5
#      h_min           :  0.3535533905932738
# -->test_fun      :
#      order       :  2
#      dof         :  25
# 2023-11-28 03:05:30.823572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_2/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_2/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_2/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_2/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:30.826123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_3/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_3/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_3/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_3/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:30.832101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:30.836452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/gradient_tape/strided_slice_1/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_1/StridedSliceGrad/strides' with dtype int32 and shape [2]
# 	 [[{{node gradients/gradient_tape/strided_slice_1/StridedSliceGrad_grad/StridedSlice/gradient_tape/strided_slice_1/StridedSliceGrad/strides}}]]
# 2023-11-28 03:05:31.016792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_2}}]]
# 2023-11-28 03:05:31.017078: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_5' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_5}}]]
# 2023-11-28 03:05:31.017242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8}}]]
# 2023-11-28 03:05:31.017503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11}}]]
# 2023-11-28 03:05:31.500240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78}}]]
# 2023-11-28 03:05:31.500439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_110' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_110}}]]
# 2023-11-28 03:05:31.500509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_132' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_132}}]]
# 2023-11-28 03:05:31.500599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_163' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_163}}]]
# 2023-11-28 03:05:31.500692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_194' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_194}}]]
# 2023-11-28 03:05:31.500798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_228' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_228}}]]
# 2023-11-28 03:05:31.500878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_273' with dtype int32 and shape [2]
# ...
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_505}}]]
# 2023-11-28 03:05:31.501613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_519' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_519}}]]
# 2023-11-28 03:05:31.501700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_531' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_531}}]]
# 2023-11-28 03:05:31.501861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_536' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_536}}]]
# 2023-11-28 03:05:31.502000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_539' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_539}}]]
# 2023-11-28 03:05:31.502092: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_542' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_542}}]]
# 2023-11-28 03:05:31.502187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_545' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_545}}]]
# Iteration: 0 loss: 2.1370674808 time: 6.225625038146973
# Iteration: 10 loss: 1.2650279592 time: 0.10088038444519043
# Iteration: 20 loss: 0.6454421589 time: 0.09354496002197266
# Iteration: 30 loss: 0.2798542756 time: 0.08636784553527832
# Iteration: 40 loss: 0.1071618327 time: 0.08422470092773438
# Iteration: 50 loss: 0.0456319222 time: 0.08655977249145508
# Iteration: 60 loss: 0.0315592359 time: 0.09084892272949219
# Iteration: 70 loss: 0.0304518214 time: 0.08919310569763184
# Iteration: 80 loss: 0.0302229371 time: 0.08082199096679688
ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> history=vp.train(1000, 0.001)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> integral,error=dblquad(lambda x,y: (u_exact(x,y)-vp.u_NN_BC(x,y))**2, 0.0, 1.0,0.0, 1.0)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> L2_error=np.sqrt(integral)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> semi_H1_err2, int_error_semi_H1 = dblquad(semi_H1_error, 0.0, 1.0, 0.0, 1.0, epsabs=5E-6)
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:601, in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     597 def temp_ranges(*args):
#     598     return [gfun(args[0]) if callable(gfun) else gfun,
#     599             hfun(args[0]) if callable(hfun) else hfun]
# --> 601 return nquad(func, [temp_ranges, [a, b]], args=args,
#     602         opts={"epsabs": epsabs, "epsrel": epsrel})
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:825, in nquad(func, ranges, args, opts, full_output)
#     823 else:
#     824     opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 825 return _NQuad(func, ranges, opts, full_output).integrate(*args)
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:879, in _NQuad.integrate(self, *args, **kwargs)
#     877 else:
#     878     f = partial(self.integrate, depth=depth+1)
# --> 879 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#     880               **opt)
#     881 value = quad_r[0]
#     882 abserr = quad_r[1]
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461 if points is None:
#     462     if infbounds == 0:
# --> 463         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464     else:
#     465         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:879, in _NQuad.integrate(self, *args, **kwargs)
#     877 else:
#     878     f = partial(self.integrate, depth=depth+1)
# --> 879 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#     880               **opt)
#     881 value = quad_r[0]
#     882 abserr = quad_r[1]
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File ~/.local/lib/python3.8/site-packages/scipy/integrate/_quadpack_py.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461 if points is None:
#     462     if infbounds == 0:
# --> 463         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464     else:
#     465         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb Cell 18 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> vp=VPINN(pb,params,mesh,model)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> history=vp.train(1000, 0.001)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> integral,error=dblquad(lambda x,y: (u_exact(x,y)-vp.u_NN_BC(x,y))**2, 0.0, 1.0,0.0, 1.0)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> L2_error=np.sqrt(integral)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/evan/IVPINN/VPINN_clean_with_BC/main.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> semi_H1_err2, int_error_semi_H1 = dblquad(semi_H1_error, 0.0, 1.0, 0.0, 1.0, epsabs=5E-6)
#
# File ~/IVPINN/VPINN_clean_with_BC/VPINN_tri_final.py:103, in VPINN.u_NN_BC(self, x, y)
#     101 def u_NN_BC(self, x, y):
#     102     eval=tf.constant([[x,y]],dtype=tf.float64)
# --> 103     return self.NN_imposeBC(eval).numpy()[0,0]
#
# File ~/IVPINN/VPINN_clean_with_BC/VPINN_tri_final.py:110, in VPINN.NN_imposeBC(self, x)
#     108 def NN_imposeBC(self,x):
#     109     eval=self.NN(x)
# --> 110     boundary=self.boundary_function(x)
#     111     return eval*tf.cast(boundary, tf.float64)
#
# File ~/IVPINN/VPINN_clean_with_BC/VPINN_tri_final.py:106, in VPINN.boundary_function(self, x)
#     105 def boundary_function(self,x):
# --> 106     return tf.expand_dims(10*x[:,0]*(1-x[:,0])*x[:,1]*(1-x[:,1]),axis=1)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py:1490, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1488 @traceback_utils.filter_traceback
#    1489 def r_binary_op_wrapper(y, x):
# -> 1490   with ops.name_scope(None, op_name, [x, y]) as name:
#    1491     # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1492     #   r_binary_op_wrapper use different force_same_dtype values.
#    1493     y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
#    1494     return func(x, y, name=name)
#
# KeyboardInterrupt:

# %%
h = np.array(h)

H1 = np.array(H1)
L2 = np.array(L2)
semi = np.array(semi)

# %%
# slope_H1, intercept_H1 = np.polyfit(h, H1, 1)
# slope_L2, intercept_L2 = np.polyfit(h, L2, 1)

coeffs = np.polyfit(np.log10(h), np.log10(H1), 1)
polynomial = np.poly1d(coeffs)
log10_H1_fit = polynomial(np.log10(h))

print(f"H1 rate: {coeffs[0]}")

coeffs = np.polyfit(np.log10(h), np.log10(L2), 1)
polynomial = np.poly1d(coeffs)
log10_L2_fit = polynomial(np.log10(h))

print(f"L2 rate: {coeffs[0]}")

plt.loglog(h, H1, marker='o', label='H1')
plt.loglog(h, L2, marker='o', label='L2')
plt.loglog(h, semi, marker='o', label='semi')
plt.loglog(h, 10**log10_H1_fit)
plt.loglog(h, 10**log10_L2_fit)
plt.loglog(h, h, linestyle=':', label='h1')
plt.loglog(h, h*h, linestyle=':', label='h2')
plt.grid()
plt.legend()
# Out:
# H1 rate: 1.2736676487331193
# L2 rate: 1.4776942334720964
